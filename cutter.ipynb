# %%
import numpy as np
import pandas as pd
import deepcut

# %%
df_ingredient = pd.read_csv('df_ingredient.csv', encoding='utf-8')
df_ingredient['ingredient']
# Out:
# 0          ผักคะน้า
# 1            หมูสับ
# 2          คนอร์หมู
# 3          น้ำมะนาว
# 4            หอมแดง
#             ...
# 31173    ซอสเห็ดหอม
# 31174    ฟองเต้าหู้
# 31175     พุทธาแห้ง
# 31176      น้ำสะอาด
# 31177         เกลือ
# Name: ingredient, Length: 31178, dtype: object

# %%
for x in df_ingredient['ingredient'].values:
    print(deepcut.tokenize(x))
# Out:
# ['ผักคะน้า']
# ['หมู', 'สับ']
# ['คน', 'อร์หมู']
# ['น้ำ', 'มะนาว']
# ['หอมแดง']
# ['พริก']
# ['น้ำปลา']
# ['น้ำเชื่อม']
# ['น้ำ', 'สะอาด']
# ['น้ำเย็น']
# ['ข้าวสีนิล']
# ['น้ำ', 'สะอาด']
# ['หมู', 'สับ']
# ['คน', 'อร์หมู']
# ['พริกไทดำ']
# ['พริกไทขาว']
# ['กระเทียม']
# ['ต้นหอม']
# ['ผักชี']
# ['ขาหมู']
# ['คน', 'อร์หมู']
# ['คน', 'อร์ลาบ']
# ['เห็ดชิเมจิขาว']
# ['ข่า']
# ['หอม', 'แดง', 'ใหญ่']
# ['ตะไคร้']
# ['มะนาว']
# ['ผักชี']
# ['ผักชี']
# ['ใบ', 'มะกรูด']
# ['พริก']
# ['ผักชี']
# ['น้ำตาล']
# ['น้ำ', 'สะอาด']
# ['แป้ง', 'โรตี']
# ['หมู', 'สับ']
# ['ไข่ไก่']
# ['คน', 'อร์หมู']
# ['คน', 'อร์ซอส']
# ['ต้นหอม']
# ['ผักชี']
# ['กระเทียม']
# ['พริกไทย']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['น้ำ', 'บ๊วย', 'พร้อม', 'เนื้อ']
# ['น้ำตาล']
# ['เกลือ']
# ['ปลาจาระเม็ด']
# ['คึ่น', 'ช่าย']
# ['พริกชี้ฟ้าแดง']
# ['ขิง']
# ['น้ำ', 'บ๊วย', 'พร้อม', 'เนื้อ', 'บ๊วย']
# ['คน', 'อร์หมู']
# ['น้ำตาล']
# ['น้ำ', 'สะอาด']
# ['เม็ด', 'มะม่วงหิมพานต์']
# ['พริก']
# ['ต้นหอม']
# ['อกไก่']
# ['คน', 'อร์ลาบ']
# ['น้ำผึ้ง']
# ['มันฝรั่ง']
# ['ข้าวโพดอ่อน']
# ['ผักสลัด']
# ['พริก']
# ['หอมแดง']
# ['ปลาทู']
# ['ซีอิ้วขาว']
# ['คน', 'อร์หมู']
# ['น้ำตาล']
# ['พริก']
# ['น้ำ', 'สะอาด']
# ['หมูกรอบ']
# ['ข้าวเปล่า']
# ['น้ำ', 'จิ้ม', 'ซี', 'ฟู้ด']
# ['พริก']
# ['ขนมปัง']
# ['นม', 'เปรี้ยว']
# ['เวเฟอร์', 'รสชาติ', 'ครีม']
# ['ส้ม']
# ['มะละกอ']
# ['น้ำผึ้ง']
# ['ข้าว', 'สวย']
# ['ปลาทู']
# ['พริก']
# ['มะนาว']
# ['หอมแดง']
# ['ต้นหอม']
# ['น้ำมันมะกอก']
# ['น้ำเปล่า']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['แหนมหมู']
# ['ข้าวโพดอ่อน']
# ['เห็ดหู', 'หนูดำ']
# ['น้ำ', 'จิ้ม', 'ซี', 'ฟู้ด']
# ['น้ำ', 'มะนาว']
# ['น้ำมันมะกอก']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['เนย']
# ['น้ำตาล']
# ['ไข่ไก่']
# ['แป้ง', 'เอนกประสงค์']
# ['น้ำตาล']
# ['น้ำตาล']
# ['ไวท์ช็อกโกแลต']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['ไข่ไก่']
# ['ชีส']
# ['น้ำมันมะกอก']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['ไข่ไก่']
# ['แฮม']
# ['หัวหอม', 'ใหญ่']
# ['ต้นหอม']
# ['ข้าวโพดอ่อน']
# ['มะนาว']
# ['ซอสมะเขือเทศ']
# ['ซีอิ้วขาว']
# ['น้ำมันมะกอก']
# ['กุ๊กกี้', 'ดาร์ก', 'ช็อกโกแลต']
# ['นม', 'กล่อง', 'แมกโนเลีย']
# ['ส้ม']
# ['มะละกอ']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['ปลาทู']
# ['ต้นหอม']
# ['เห็ดหู', 'หนูดำ']
# ['ข้าวโพดอ่อน']
# ['พริกไทดำ']
# ['น้ำตาล']
# ['พริก']
# ['กระเทียม']
# ['น้ำมันมะกอก']
# ['แฮม']
# ['ไข่ไก่']
# ['น้ำมันมะกอก']
# ['เงาะ']
# ['น้ำ', 'เชื่อม', 'สำเร็จรูป']
# ['น้ำเปล่า']
# ['เกลือ']
# ['น้ำ', 'แข็ง']
# ['คื่นช่าย', 'ฝรั่ง']
# ['ปลาทู']
# ['น้ำเปล่า']
# ['พริก']
# ['กระเทียม']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['น้ำมันมะกอก']
# ['ขนมปัง']
# ['ชีส']
# ['หมูหยอง']
# ['ไข่ไก่']
# ['แหนมหมู']
# ['ต้นหอม']
# ['ซีอิ้วขาว']
# ['พริกไทย']
# ['ปี', 'โป้']
# ['มะนาว']
# ['โยเกิร์ต']
# ['องุ่น']
# ['สัปปะรด']
# ['กีวี']
# ['แอปเปิ้ล', 'แดง']
# ['แอปเปิ้ล', 'เขียว']
# ['มังคุด']
# ['งาดำ']
# ['เป็ด', 'ย่าง']
# ['น้ำ', 'จิ้ม', 'เป็ด', 'ย่าง']
# ['น้ำสลัด']
# ['น้ำ', 'มะนาว']
# ['ผักสลัด']
# ['แตงกวา']
# ['มะเขือเทศ']
# ['หอม', 'ใหญ่']
# ['มะนาว']
# ['งาดำ']
# ['น้ำสลัด']
# ['ฟิงเกอร์', 'รส', 'ซาวครีม']
# ['ข้าว', 'เกียบ', 'ปลา']
# ['กล้วย']
# ['ข้าวทอด']
# ['ข้าวตัง']
# ['ขนม', 'ข้าว', 'อบกรอบ', 'ผสม', 'ข้าวไรซ์เบอร์รี่']
# ['ลูกชิ้น', 'หมู']
# ['ผัดสลัด']
# ['มา', 'ยองเนส']
# ['แตงกวา']
# ['ข้าวโพดอ่อน']
# ['มะเขือเทศ']
# ['งาดำ']
# ['ซอสพริก']
# ['ซอสมะเขือเทศ']
# ['น้ำ', 'มะนาว']
# ['กุ้ง']
# ['ใบ', 'คื่น', 'ช่าย']
# ['พริก']
# ['กระเทียม']
# ['มะนาว']
# ['น้ำเปล่า']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['น้ำมัน', 'สำหรับ', 'ผัด']
# ['คื่นช่าย', 'ฝรั่ง']
# ['น้ำผึ้ง']
# ['กุ้ง']
# ['ผัดสลัด']
# ['น้ำ', 'จิ้ม', 'ซี', 'ฟู้ด']
# ['น้ำสลัด']
# ['น้ำผึ้ง']
# ['ดอกแค']
# ['หมู', 'สาม', 'ชั้น']
# ['พริก']
# ['หอม', 'หัวใหญ่']
# ['ต้นหอม']
# ['มะเขือเทศ', 'ลูก', 'ใหญ่']
# ['แครอท']
# ['มะนาว']
# ['ซีอิ้วขาว']
# ['ซอสพริก']
# ['ซอสมะเขือเทศ']
# ['น้ำตาล']
# ['ดอกแค']
# ['หมู', 'สาม', 'ชั้น']
# ['มะนาว']
# ['น้ำ', 'จิ้ม', 'ซี', 'ฟู้ด']
# ['โยเกิร์ต']
# ['มะม่วงกวน']
# ['หมู', 'สับ']
# ['คน', 'อร์ซอส']
# ['คน', 'อร์ลาบ']
# ['พริก', 'แห้ง']
# ['หอมแดง']
# ['ต้นหอม']
# ['ผักชี']
# ['ใบ', 'สาระแหน่']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ผักเคียง']
# ['เต้าหู้', 'ขาว']
# ['น้ำ', 'มะขาม', 'เปียก']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['หอมแดง']
# ['ใบ', 'สาระแหน่']
# ['พริก', 'แห้ง']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ถั่วลันเตา']
# ['เนื้อหมู']
# ['กระเทียม']
# ['น้ำเปล่า']
# ['ซีอิ้วขาว']
# ['น้ำพริก', 'เผา']
# ['น้ำมัน', 'หอย']
# ['น้ำตาล']
# ['น้ำมัน', 'สำหรับ', 'ผัด']
# ['กล้วย']
# ['กล้วน้ำ', 'ว้า']
# ['แป้ง', 'ข้าวโพด']
# ['น้ำเย็น']
# ['เกลือ']
# ['น้ำผึ้ง']
# ['นม', 'ข้นหวาน']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['หมู', 'สับ']
# ['ไข่ไก่']
# ['ต้นหอม']
# ['คน', 'อร์หมู']
# ['ซีอิ้วขาว']
# ['ซอสหอยนางรม']
# ['พริกไทย']
# ['น้ำเปล่า']
# ['ขนมปัง']
# ['กล้วย']
# ['นม', 'ข้นหวาน']
# ['นม', 'ขนหวาน', 'รสช็อ', 'โกแลต']
# ['เนื้อหมู']
# ['ซีอิ้วขาว']
# ['น้ำผึ้ง']
# ['พริกไทย', 'ป่น']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ผักกาดดอง']
# ['หมู', 'สาม', 'ชั้น']
# ['คน', 'อร์ซอส']
# ['น้ำเปล่า']
# ['กระเทียม']
# ['น้ำมัน', 'สำหรับ', 'ผัด']
# ['นม', 'ช็อกโกแลตนัทตี้']
# ['กล้วย']
# ['มะละกอ']
# ['บล็อกโคลี่']
# ['กะหล่ำ']
# ['เห็น', 'ชิเมจิ']
# ['ข้าวโพดอ่อน']
# ['แครอท']
# ['ผักกวางตุ้ง']
# ['ผักกาดขาว']
# ['กะหล่ำ']
# ['มะเขือเทศ']
# ['หอม', 'หัวใหญ่']
# ['น้ำเปล่า']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['ซอสหอยนางรม']
# ['พริก']
# ['กระเทียม']
# ['น้ำมัน', 'สำหรับ', 'ผัด']
# ['พริกไทย']
# ['ขนมปัง']
# ['นม', 'ข้นหวาน']
# ['ดาร์ก', 'ช็อกโกแลต']
# ['เนื้อหมู']
# ['กระเทียม']
# ['แป้ง', 'ข้าวโพด']
# ['ซีอิ้วขาว']
# ['ซอสหอยนางรม']
# ['น้ำตาล']
# ['พริกไทย']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['หมู', 'สับ']
# ['กระเทียม']
# ['พริกไทดำ']
# ['แป้ง', 'ข้าวโพด']
# ['ซีอิ้วขาว']
# ['ซอสหอยนางรม']
# ['หัวหอม']
# ['ต้นหอม']
# ['ผักชี']
# ['ขนมปัง']
# ['ทูน่า']
# ['มะเขือเทศ']
# ['แตงกวา']
# ['แครอท']
# ['หอม', 'หัวใหญ่']
# ['ผักสลัด']
# ['ต้นหอม']
# ['กล้วย']
# ['น้ำ', 'สด']
# ['ขนมข้าวแต๋น']
# ['นม', 'ข้นหวาน']
# ['ไข่']
# ['ข้าวเปล่า']
# ['หอม', 'หัวใหญ่']
# ['แครอท']
# ['ต้น', 'หอม', 'ตาม', 'ชอบ']
# ['มะเขือเทศ']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['พริกไทย']
# ['น้ำมัน', 'สำหรับ', 'ผัด']
# ['โยเกิร์ต']
# ['ขนุน']
# ['มะละกอ', 'สุก']
# ['น้ำผึ้ง']
# ['กล้วย']
# ['เม็ด', 'ทานตะวัน']
# ['โยเกิร์ต']
# ['มะเขือเทศ']
# ['หมูยอ']
# ['แครอท']
# ['ข้าวโพดอ่อน']
# ['ซอสหอยนางรม']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['น้ำปลา']
# ['น้ำเปล่า']
# ['พริกไทย']
# ['กระเทียม']
# ['ไข่ไก่']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['น้ำปลา']
# ['พริกไทย']
# ['หมี่กรอบ']
# ['น้ำเปล่า']
# ['น้ำตาล']
# ['ซอสมะเขือเทศ']
# ['ถั่วลิสง']
# ['น้ำ', 'แดงเฮบลูบ', 'อย']
# ['น้ำ', 'มะนาว']
# ['ปี', 'โป้']
# ['น้ำเปล่า']
# ['ตับหมู']
# ['กระเทียม']
# ['ผักชี']
# ['พริกไทย']
# ['น้ำมัน', 'หอย']
# ['น้ำตาล']
# ['น้ำปลา']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['น้ำสลัด']
# ['น้ำสลัด']
# ['น้ำ', 'จิ้ม', 'ซี', 'ฟู้ด']
# ['ผักเรดโอ๊ก']
# ['ผักกาดหอม']
# ['แครอท']
# ['มะเขือเทศ']
# ['มะละกอ']
# ['ปลาซาบะ']
# ['นมสด']
# ['น้ำผึ้ง']
# ['นมสด']
# ['ทอปเบอโรน', ' ', 'ดาร์ก', 'ช็อกโกแลตก้อน']
# ['หมู', 'สัน', 'นอก']
# ['มะนาว']
# ['น้ำปลา']
# ['น้ำ', 'เชื่อม', 'สำเร็จรูป']
# ['พริกเขียว']
# ['พริกแดง']
# ['กระเทียม']
# ['ผักกาดหอม']
# ['น้ำ', 'สะอาด', 'สำหรับ', 'ลวก', 'หมู']
# ['หอยแมลงภู่ลวก', 'แกะ']
# ['หอยแครงลวกแกะ']
# ['มะนาว']
# ['ตะไคร้']
# ['หอม', 'แดง', 'เล็ก']
# ['ใบ', 'สะระ', 'แหน่']
# ['พริก']
# ['น้ำปลา']
# ['น้ำ', 'เชื่อม', 'สำเร็จรูป']
# ['ถั่วลิสง']
# ['คน', 'อร์หมู']
# ['หมู', 'สับ']
# ['ไข่ไก่']
# ['ซีอิ้วขาว']
# ['น้ำเปล่า']
# ['หมู', 'สับ']
# ['เส้น', 'หมี่', 'ข้าว', 'กล้อง']
# ['พริก']
# ['มะนาว']
# ['คน', 'อร์หมู']
# ['น้ำตาล']
# ['กระเทียม']
# ['น้ำ', 'สะอาด']
# ['น้ำมัน', 'มะพร้าว']
# ['พริกไทดำ']
# ['เส้นหมี่']
# ['ไข่ไก่']
# ['ผักกวางตุ้ง']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'หอย']
# ['น้ำตาล']
# ['น้ำมัน', 'มะพร้าว']
# ['น้ำมัน', 'มะพร้าว']
# ['น้ำ', 'สะอาด', 'สำหรับ', 'ต้ม', 'หมี่']
# ['กระเทียม']
# ['ข้าวเปล่า']
# ['ปลากรอบ']
# ['พริก', 'แกงเผ็ด']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['พริก']
# ['มะนาว']
# ['แป้ง', 'อเนกประสงค์']
# ['แป้งเค้ก']
# ['โกโก้']
# ['น้ำเชื่อม']
# ['มาการีน']
# ['ผักกาดขาว']
# ['กระเทียม']
# ['น้ำมัน', 'หอย']
# ['ซี้', 'อิ้วขาว']
# ['น้ำตาล']
# ['น้ำ', 'สะอาด', 'สำหรับ', 'ลวก', 'ผัก']
# ['น้ำเย็น']
# ['น้ำมัน', 'งา']
# ['อกไก่']
# ['ผักบุ้ง']
# ['เห็ด', 'โคนขาว', 'หิมะ']
# ['ผักกาดขาว']
# ['คน', 'อร์หมู']
# ['น้ำ', 'สะอาด']
# ['ไข่ไก่']
# ['ซีอิ้วขาว']
# ['พริกไทดำ']
# ['น้ำเปล่า']
# ['ซอสพริก']
# ['ซอสมะเขือเทศ']
# ['งาดำ', 'คั่ว']
# ['น้ำ', 'มะนาว']
# ['กระเทียม']
# ['น้ำปลา']
# ['น้ำเชื่อม']
# ['น้ำมัน', 'งา']
# ['กระเทียม']
# ['พริกแดงจินดา']
# ['ผักชี']
# ['สัน', 'ใน', 'ไก่']
# ['ไข่ไก่']
# ['ซอสพริก']
# ['ซอสมะเขือเทศ']
# ['ซีอิ้วขาว']
# ['น้ำผึ้ง']
# ['หอม', 'ใหญ่']
# ['ต้นหอม']
# ['น้ำมัน', 'มะพร้าว']
# ['มัน', 'ม่วง', 'นึ่ง']
# ['นมสดรสหวาน']
# ['แป้ง', 'สาลี', 'อเนกประสงค์']
# ['น้ำเชื่อม']
# ['งาขาว']
# ['ผง', 'ฟู']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ซีโครงไก่']
# ['น้ำเปล่า']
# ['นมสดรสหวาน']
# ['น้ำพริก', 'เผา']
# ['น้ำ', 'มะนาว']
# ['ซีอิ้วขาว']
# ['น้ำผึ้ง']
# ['กะปิ']
# ['พริกชี้ฟ้าแดง']
# ['พริกขี้หนู']
# ['มะเขือเทศ']
# ['ตะไคร้']
# ['เห็ดฟาง']
# ['ใบ', 'มะกูด']
# ['ต้นหอม']
# ['ข่า']
# ['พริกขี้หนู']
# ['มะนาว']
# ['น้ำปลา']
# ['น้ำเชื่อม']
# ['กระเทียม']
# ['น้ำเปล่า']
# ['ผักชี']
# ['สัน', 'ใน', 'ไก่']
# ['โยเกิร์ต']
# ['น้ำผึ้ง', 'หมัก', 'ไก่']
# ['ผักชี']
# ['เกล็ด', 'ขนมปัง']
# ['สูตร', 'น้ำ', 'จิ้ม', 'มา', 'ยองหวาน']
# ['มา', 'ยองเนส']
# ['น้ำผึ้ง']
# ['งาดำ']
# ['สูตร', 'น้ำ', 'จิ้ม', 'มา', 'ยอง', 'เปรี้ยว']
# ['น้ำ', 'มะนาว']
# ['ผิว', 'มะนาว']
# ['สูตร', 'น้ำ', 'จิ้ม', 'มา', 'ยอง', 'เผ็ด']
# ['ซี้', 'อิ้วขาว', 'สูตร', 'ลด', 'โซเดี่ยม']
# ['พริกแดงจินดา']
# ['กระเทียม']
# ['ผักชี']
# ['พริกป่น']
# ['ปีกไก่']
# ['แป้ง', 'ทอด', 'กรอบ', 'สำเร็จรูป']
# ['น้ำเย็น']
# ['กระชาย']
# ['พริกไทย', 'อ่อน']
# ['ใบ', 'มะกูด']
# ['พริกชี้ฟ้าแดง']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['น้ำเปล่า']
# ['น้ำมัน', 'มะพร้าว']
# ['อกไก่']
# ['ขิง']
# ['พริกหยวก', 'เขียว']
# ['หอม', 'หัวใหญ่']
# ['เห็ดหู', 'หนูดำ']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['ซอสหอยนางรม']
# ['กระเทียม']
# ['น้ำเปล่า']
# ['น้ำมัน', 'มะพร้าว']
# ['ข้าวโพดอ่อน']
# ['สัน', 'ใน', 'ไก่']
# ['ปลาหมึก']
# ['กุ้ง']
# ['ซอสพริกศรีราชา']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['น้ำเปล่า']
# ['กระเทียม']
# ['พริกไทดำ']
# ['น้ำมัน', 'มะพร้าว']
# ['หน่อไม้ฝรั่ง']
# ['กุ้ง']
# ['ต้นหอม']
# ['ซอสหอยนางรม']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['น้ำมัน', 'งา']
# ['น้ำเปล่า']
# ['พริกไทดำ']
# ['หน่อไม้ฝรั่ง']
# ['กุ้ง']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['แป้ง', 'ข้าวโพด']
# ['น้ำเปล่า']
# ['น้ำมัน', 'มะพร้าว']
# ['ไข่ไก่']
# ['กุ้ง']
# ['ต้นหอม']
# ['หอม', 'หัวใหญ่']
# ['ข้าวโพดอ่อน']
# ['พริก']
# ['ใบ', 'โหรพา']
# ['ชีส']
# ['พริกไทดำ']
# ['คน', 'อร์หมู']
# ['ซอสพริกศรีราชา']
# ['น้ำมัน', 'มะพร้าว']
# ['กุ้ง']
# ['ปลาหมึก']
# ['ใบ', 'กระเพรา']
# ['ข้าวโพดอ่อน']
# ['พริก']
# ['กระเทียม']
# ['น้ำตาล']
# ['คน', 'อร์หมู']
# ['ซี่อิ้วขาว']
# ['น้ำเปล่า']
# ['น้ำมัน', 'มะพร้าว']
# ['กล้วย']
# ['แป้ง', 'สาลี', 'อเนกประสงค์']
# ['ถั่วลิสง']
# ['งาขาว']
# ['น้ำเปล่า']
# ['น้ำมัน', 'มะพร้าว']
# ['กุ้ง']
# ['พริก']
# ['กระเทียม']
# ['แป้ง', 'สาลี', 'อเนกประสงค์']
# ['เกลือ']
# ['น้ำตาล']
# ['ผักชี']
# ['น้ำมัน', 'มะพร้าว']
# ['คางกุ้ง']
# ['แป้ง', 'ทอด', 'กรอบ', 'สำเร็จ']
# ['เกล็ด', 'ขนมปัง']
# ['คน', 'อร์หมู']
# ['พริกไทย']
# ['น้ำมัน', 'รำข้าว', 'สำหรับ', 'ทอด']
# ['บวบ']
# ['กุ้ง']
# ['คน', 'อร์หมู']
# ['น้ำตาล']
# ['กระเทียม']
# ['น้ำมัน', 'รำข้าว']
# ['น้ำ', 'สะอาด']
# ['ปลาฉิงฉาง']
# ['น้ำเปล่า']
# ['น้ำตาล']
# ['งาดำ']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['แตงกวา']
# ['ทูน่า']
# ['พริก']
# ['หอม', 'หัวใหญ่']
# ['ผักสลัด']
# ['น้ำ', 'เลม่อน']
# ['แตงกวา']
# ['ผักสลัด']
# ['หอม', 'หัวใหญ่']
# ['ข้าวโพดต้ม']
# ['ถั่วลิสง']
# ['มา', 'ยองเนส']
# ['ซอสพริก']
# ['ซอสมะเขือเทศ']
# ['ไข่ไก่']
# ['ผักกากขาว']
# ['ถั่วลิสง']
# ['พริกขี้หนู']
# ['กระเทียม']
# ['น้ำเปล่า']
# ['น้ำมัน', 'รำข้าว']
# ['คน', 'อร์ซอส']
# ['เกลือ']
# ['พริกไทย']
# ['หมู', 'สาม', 'ชั้น']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['น้ำโค้ก']
# ['คน', 'อร์หมู']
# ['น้ำตาล']
# ['พริกขี้หนู']
# ['พริกป่น']
# ['กระเทียม']
# ['มัน', 'หมู']
# ['หนังหมู']
# ['คน', 'อร์หมู']
# ['น้ำส้มสายชู']
# ['หมู', 'สาม', 'ชั้น']
# ['คน', 'อร์หมู']
# ['น้ำตาล']
# ['พริก', 'แกงเผ็ด']
# ['แป้ง', 'ทอด', 'สำเร็จ']
# ['กระเทียม']
# ['หอมแดง']
# ['พริก', 'แห้ง']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['หมู', 'สาม', 'ชั้น']
# ['เห็ดเข็มทอง']
# ['กระเทียม']
# ['น้ำมันมะกอก']
# ['น้ำตาล']
# ['คน', 'อร์หมู']
# ['แป้ง', 'ข้าวเจ้า']
# ['น้ำลอยมะลิ']
# ['น้ำตาล']
# ['เนย']
# ['เนย']
# ['เกลือ']
# ['ปลาสลิด']
# ['เห็ดหู', 'หนู', 'ขาว']
# ['คน', 'อร์หมู']
# ['มะเขือเทศ']
# ['คื่นช่าย']
# ['หอมแดง']
# ['พริก']
# ['ข้าวโพดอ่อน']
# ['น้ำเปล่า']
# ['น้ำตาล']
# ['มะนาว']
# ['น้ำปลา']
# ['แป้งเค้ก']
# ['โกโก้']
# ['เนย']
# ['ดาร์ก', 'ช็อกโกแลต']
# ['ไข่ไก่']
# ['ไข่แดง']
# ['น้ำตาล']
# ['นมสด']
# ['ผักบุ้ง']
# ['ไข่', 'ขาว']
# ['คน', 'อร์หมู']
# ['น้ำเปล่า']
# ['พริก']
# ['น้ำตาล']
# ['น้ำมันมะกอก']
# ['กระเทียม']
# ['ไข่ไก่']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['ชีส']
# ['คน', 'อร์หมู']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['หมู', 'สับ']
# ['ไข่ไก่']
# ['หอม', 'หัวใหญ่']
# ['แครอท']
# ['บล็อกโคลี่']
# ['พริก']
# ['กระเทียม']
# ['มะนาว']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['พริกไทย']
# ['กระปิ']
# ['น้ำมันมะกอก']
# ['หมู', 'สัน', 'นอก']
# ['ใบ', 'มะกรูด', 'หั่น', 'เส้นบาง']
# ['มะนาว']
# ['พริกชี้ฟ้าใหญ่']
# ['พริกแกง', 'ใต้', 'เผ็ด', 'มาก']
# ['หัว', 'กระทิ']
# ['น้ำปลา']
# ['น้ำตาล']
# ['น้ำมันมะกอก']
# ['ผักแกล้ม']
# ['หมู', 'สัน', 'นอก']
# ['มะเขือเทศ']
# ['หอม', 'หัวใหญ่']
# ['พริกไทดำ']
# ['เกลือ']
# ['น้ำ', 'มะนาว']
# ['เนย']
# ['บล็อกโคลี่']
# ['หมู', 'สับ']
# ['พริกขี้หนู']
# ['กระเทียม']
# ['น้ำเปล่า']
# ['ซีอิ้วขาว']
# ['ซอสหอยนางรม']
# ['น้ำมันมะกอก']
# ['พริกชี้ฟ้า', 'แดง', 'ใหญ่']
# ['ปลาทู']
# ['เห็ด', 'นางฟ้า']
# ['ข่า']
# ['ตะไคร้']
# ['ใบ', 'มะกรูด']
# ['มะนาว']
# ['ผักชี']
# ['น้ำปลา']
# ['น้ำเชื่อม']
# ['พริกขี้หนู', '+', 'พริกชี้ฟ้าแดง']
# ['น้ำเปล่า']
# ['เกลือ']
# ['หอมแดง']
# ['สัปปะรด']
# ['เกลือ']
# ['น้ำผึ้ง']
# ['ปลากระป๋อง']
# ['ผักคะน้า']
# ['ซีอิ้วขาว']
# ['น้ำเปล่า']
# ['พริกขี้หนู']
# ['กระเทียม']
# ['ข้าวโพดอ่อน']
# ['อะโวคาโด']
# ['นมสด']
# ['คะน้า']
# ['ปลา', 'แห้ง']
# ['น้ำเปล่า']
# ['ซอสหอยนางรม']
# ['น้ำมัน', 'งา']
# ['น้ำปลา']
# ['กระเทียม']
# ['พริกขี้หนู']
# ['เฉาก๊วย']
# ['นมสดรสจืด']
# ['น้ำแดง']
# ['น้ำตาล']
# ['น้ำ', 'แข็ง']
# ['ต้น', 'อ่อนทาน', 'ตะวัน']
# ['น้ำมัน', 'หอย']
# ['ซีอิ้วขาว']
# ['กระเทียม']
# ['หมู', 'สาม', 'ชั้น']
# ['ซอสโซยุ']
# ['น้ำผึ้ง']
# ['น้ำมันมะกอก']
# ['ซี่', 'โครง', 'หมู']
# ['ฟัก', 'เขียว']
# ['ผักชี']
# ['กระเทียม']
# ['พริกไทขาว']
# ['คน', 'อร์หมู']
# ['น้ำเปล่า']
# ['โยเกิร์ต']
# ['นมสดรสจืด']
# ['น้ำผึ้ง']
# ['มะนาว']
# ['ปลาข้าวสาร']
# ['ผักสลัด']
# ['น้ำสลัด']
# ['น้ำ', 'จิ้ม', 'ซี', 'ฟู้ด']
# ['พริกขี้หนู']
# ['กระเทียม']
# ['มะนาว']
# ['ปลาข้าวสาร']
# ['น้ำพริก', 'เผา']
# ['น้ำเปล่า']
# ['น้ำเชื่อม']
# ['งาดำ']
# ['น้ำ', 'มะนาว']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['แป้ง', 'ถั่วเขียว']
# ['แป้ง', 'เอนกประสงค์']
# ['เกลือ']
# ['ผง', 'ฟู']
# ['ไข่']
# ['น้ำตาล']
# ['เนย']
# ['น้ำเปล่า']
# ['เนย']
# ['แซลม่อน']
# ['น้ำเปล่า']
# ['เลม่อน']
# ['น้ำ', 'เชื่อม', 'สำเร็จรูป']
# ['น้ำปลา']
# ['แครอท']
# ['กระเทียม']
# ['พริกไทย']
# ['น้ำมันมะกอก']
# ['แป้ง', 'ถั่ว', 'เขียว', 'ตรา', 'ต้น', 'สน']
# ['แป้งมัน']
# ['เนย']
# ['น้ำเปล่า']
# ['น้ำตาล']
# ['กลิ่น', 'ใบเตย']
# ['สี', 'ผสม', 'อาหาร', 'สี', 'เขียว']
# ['ไข่', 'ต้ม']
# ['กะปิ']
# ['น้ำตาล']
# ['น้ำปลา']
# ['น้ำเปล่า']
# ['พริกขึ้หนู']
# ['กระเทียม']
# ['มะนาว']
# ['สัน', 'ใน', 'ไก่']
# ['หัวหอม', 'ใหญ่']
# ['มะเขือเทศ']
# ['มะนาว']
# ['พริกไทดำ']
# ['พริก']
# ['น้ำตาล']
# ['กระเทียม']
# ['เนื้อหมู']
# ['ใบ', 'กระเพรา']
# ['น้ำเปล่า']
# ['ซีอิ้วขาว']
# ['ซอสหอยนางรม']
# ['น้ำตาล']
# ['พริก']
# ['กระเทียม']
# ['น้ำมันมะกอก']
# ['ปีกไก่']
# ['ใบ', 'กระเพรา']
# ['น้ำเปล่า']
# ['ซอสหอยนางรม']
# ['ซอสปรุงรส', 'ฝาเขียว']
# ['น้ำตาล']
# ['น้ำปลา']
# ['พริก']
# ['กระเทียม']
# ['น้ำมัน', 'ปาล์ม', 'สำหรับ', 'ทอด', 'ไก่']
# ['น้ำมันมะกอก']
# ['หอม', 'ใหญ่']
# ['แป้ง', 'ทอด', 'กรอบ', 'สำเร็จรูป']
# ['เกล็ด', 'ขนมปัง']
# ['ผง', 'ลาบ']
# ['พริกไทย']
# ['น้ำเปล่า']
# ['วุ้นเส้น']
# ['กุ้ง']
# ['เนื้อหมู']
# ['หอม', 'ใหญ่']
# ['แครอท']
# ['มะเขือเทศ']
# ['มะนาว']
# ['พริกขี้หนู']
# ['ขึ้น', 'ช่าย']
# ['ปีกไก่']
# ['แป้ง', 'ทอด', 'กรอบ']
# ['น้ำเปล่า']
# ['น้ำมัน', 'งา']
# ['พริกไทย']
# ['กระเทียม']
# ['ผง', 'ปรุงรส']
# ['ชาdilmah', ' ', 'ของ', 'ประเทศศรีรังกา']
# ['ครีม', 'เทียม', 'พร่อง', 'ไขมัน']
# ['นม', 'ข้นหวาน']
# ['วุ้น', 'ปี', 'โป้']
# ['น้ำตาล']
# ['ไข่ไก่']
# ['ดาร์ก', 'ช็อกโกแลต']
# ['เนย']
# ['แป้งเค้ก']
# ['น้ำ', 'ส้ม', ' ', '(', 'ส้มนาเวล', ')']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['กุ้ง']
# ['แป้ง', 'ทอด', 'กรอบ', 'สำเร็จรูป']
# ['เกล็ด', 'ขนมปัง']
# ['น้ำมันมะกอก']
# ['เนื้อหมู']
# ['แป้ง', 'ทอด', 'กรอบ', 'สำเร็จรูป']
# ['เกล็ด', 'ขนมปัง']
# ['ผง', 'ลาบ']
# ['พริกไทย']
# ['กระเทียม']
# ['ใบ', 'ชาจีน']
# ['น้ำเปล่า']
# ['เลม่อน']
# ['น้ำผึ้ง']
# ['แป้ง', 'ถั่วเขียว']
# ['แป้ง', 'อเนกประสงค์']
# ['น้ำ', 'ปูน', 'ใส']
# ['ไข่ไก่']
# ['น้ำตาล']
# ['น้ำตาล']
# ['ไข่', 'ขาว']
# ['ไข่', 'ขาว']
# ['น้ำ', 'มะนาว']
# ['น้ำตาล']
# ['น้ำตาล']
# ['ฝอยทอง']
# ['มัน', 'เผา', ' ', 'หรือ', 'มัน', 'ต้ม']
# ['แป้ง', 'อเนกประสงค์']
# ['น้ำ', 'กระทิ']
# ['น้ำตาล']
# ['ผง', 'ฟู']
# ['เกลือ']
# ['ปลาทู']
# ['น้ำ', 'มะขาม', 'เปียก', 'เข้มข้น']
# ['น้ำตาล']
# ['น้ำปลา']
# ['น้ำเปล่า']
# ['ผักชี']
# ['นมสด']
# ['งา', 'แผ่น', 'ผสม', 'น้ำผึ้ง', 'อบกรอบ']
# ['เมล็ด', 'ฟักทอง']
# ['อัลมอนด์']
# ['เนย']
# ['น้ำ', 'เชื่อม', 'สำเร็จรูป']
# ['ขนม', 'ตุ๊บตั๊ม']
# ['ไข่ไก่']
# ['วานิลลา']
# ['แป้ง', 'อเนกประสงค์']
# ['เกลือ']
# ['บราว', 'นี่', 'ดาร์ก', 'ช็อกโกแลต']
# ['นมสด']
# ['กล้วย']
# ['ส้ม']
# ['แอปเปิ้ล']
# ['เงาะ']
# ['ดาร์ก', 'ช็อกโกแลต']
# ['นมสด']
# ['น้ำตาล']
# ['ไขขาว']
# ['แป้ง', 'สาลี', 'อเนกประสงค์']
# ['โกโก้']
# ['เกลือ']
# ['เบคกิ้งโซดา']
# ['วานิลลา']
# ['แป้ง', 'สาลี', 'อเนกประสงค์']
# ['หัว', 'กระทิ']
# ['น้ำมัน', 'พีช']
# ['พริกไทย']
# ['น้ำ']
# ['น้ำตาล']
# ['เกลือ']
# ['ผักชี']
# ['กระเทียม']
# ['มะพร้าว', 'เผา']
# ['โยเกิร์ต']
# ['ไข่ไก่']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['ปลากรอบ']
# ['หอม', 'หัวใหญ่']
# ['น้ำมันมะกอก']
# ['ไข่', 'เป็ด']
# ['เกลือ']
# ['น้ำ', 'สะอาด']
# ['สารส้ม']
# ['ขนมปัง']
# ['หมูหยอง']
# ['สลัด', 'ครีม']
# ['พริกจินดา', 'แห้ง', '(', 'ใช้', 'พริกขี้หนู', 'สด', 'ได้', ')']
# ['กระเทียม']
# ['ขมิ้นยาว', ' ', '2', ' ', 'นิ้ว']
# ['กะปิ']
# ['เกลือ']
# ['มะรุม']
# ['ปลา', 'ช่อน']
# ['พริก', 'แกงส้ม', 'ใต้']
# ['น้ำ', 'มะขาม', 'เปียก']
# ['น้ำตาล']
# ['เกลือ']
# ['น้ำ', 'สะอาด', ' ', 'พอ', 'ประมาณ']
# ['หน่อไม้รวก']
# ['ใบ', 'ย่านาง']
# ['ตะไคร้']
# ['กระชาย']
# ['กะปิ']
# ['เกลือ']
# ['น้ำตาล']
# ['น้ำ', 'สะอาด']
# ['เต้า', 'หู้', 'ขาว', 'แข็ง']
# ['เกล็ด', 'ขนมปัง']
# ['แครอทซอย']
# ['มะม่วงซอย']
# ['พริกจินดาแดงซอย']
# ['เข่ง', 'ไฉ่', '(', 'คึ่น', 'ไฉ้', ')']
# ['มะนาว', ' ', '(', ' ', 'น้ำยำ', ' ', ')']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['เม็ด', 'มะม่วงหิมพานต์']
# ['นำ', 'มัน', 'สำหรับ', 'ทอด']
# ['พริกชี้ฟ้าแดง']
# ['น้ำเปล่า']
# ['น้ำส้มสายชู']
# ['น้ำตาล']
# ['เกลือ']
# ['หัว', 'ผักกาด', ' ', '(', ' ', 'ไฉ้เท๊า', ' ', ')', ' ', '1', ' ', 'หัว']
# ['เห็ดหอม']
# ['เข่งไฉ่', ' ', '(', ' ', 'คึ่น', 'ไฉ้', ' ', ')']
# ['ถั่วลิสง']
# ['แป้ง', 'ข้าวเจ้า']
# ['แป้งมัน']
# ['น้ำตาล']
# ['เกลือ']
# ['เกลือ']
# ['พริกไทย', 'ป่น']
# ['แผ่น', 'ฟอง', 'เต้า', 'หู้', ' ', '(', ' ', 'หู่เมาะ', ' ', ')']
# ['น้ำ', 'เต้า', 'หู้', 'ทั้งหมด', 'จาก', 'ถั่ว']
# ['เจียะกอ', ' ', '(', 'ผง', 'ยิปซั่ม', ')']
# ['น้ำ', 'สะอาด']
# ['เต้าหู้', 'ดำ']
# ['ถั่วฝักยาว']
# ['พริกเหลือง', ' ', '(', ' ', 'ตำ', ' ', ')']
# ['พริกเหลือง', ' ', '(', ' ', 'ซอย', ' ', ')']
# ['ซอสเห็ด', 'หอม']
# ['น้ำมัน', 'พืช']
# ['เส้น', 'สปาเก็ตตี้', 'เบอร์']
# ['เห็ดออรินจิ']
# ['เพสโต้ซอส', ' ', '(', ' ', 'มังฯ', ' ', ')']
# ['มะเขือเทศ']
# ['ผง', 'ชาเขียว', 'มัชฉะ']
# ['น้ำเปล่า']
# ['น้ำเชื่อม']
# ['นม', 'ข้นหวาน']
# ['นมอัลม่อนด์']
# ['น้ำ', 'แข็ง']
# ['แกงฮังเล']
# ['ผัด', 'หน่อไม้ดอง']
# ['วุ้น', 'เส้น', 'ห่อ', 'เล็ก']
# ['มะเขือ', 'ต่างๆ']
# ['ถั่วฝักยาว']
# ['เห็ดออรินจิ']
# ['พริก', 'แกง', 'เผ็ด', '+', 'ผง', 'ฮินเล', '+', 'ผง', 'กะหรี่']
# ['ยอด', 'ชะอม', '+', 'ยอด', 'ผักหวาน']
# ['ซีอิ้วขาว']
# ['ตะไคร้', '+', 'ใบ', 'มะกรูด']
# ['หมู', 'สับ']
# ['เห็ด', 'ออริน', 'จิสับ']
# ['พริก', 'แกง', 'คั่ว', 'กลิ้ง']
# ['ซีอิ้วขาว']
# ['ใบ', 'มะกรูด', 'ซอย']
# ['แป้งเค้ก']
# ['เนย']
# ['น้ำตาล']
# ['เกลือ']
# ['มันม่วง', 'สุก']
# ['เต้า', 'หู้', '(', 'ทำ', 'เอง', ')']
# ['คึ่น', 'ไฉ่']
# ['พริกแดงจินดา']
# ['กระเทียม']
# ['ซีอิ้วขาว']
# ['อัลมอนด์']
# ['อัลมอนด์']
# ['โกโก้']
# ['เมเปิ้ล', 'ไซรัป', ' ', '(', ' ', 'ฐาน', ' ', ')']
# ['น้ำมัน', 'มะพร้าว']
# ['เกลือ']
# ['เนย']
# ['น้ำ', 'สะอาด', ' ', '(', ' ', 'ครีม', ' ', ')']
# ['เมเปิ้ล', 'ไซรัป', ' ', '(', ' ', 'ครีม', ' ', ')']
# ['น้ำมัน', 'มะพร้าว']
# ['เกลือ']
# ['โกโก้']
# ['น้ำมัน', 'มะพร้าว']
# ['เมเปิ้ล', 'ไซรัป', ' ', '(', ' ', 'ท็อป', ' ', ')']
# ['หมู', 'สาม', 'ชั้น']
# ['พริก', 'แห้ง']
# ['หอมแดง']
# ['กระเทียม']
# ['ตะไคร้']
# ['ข่า']
# ['กะปิ']
# ['ซีอิ้วขาว']
# ['ส้มมะขาม']
# ['นำ', 'ตาล', 'ปี๊ป']
# ['คน', 'อร์หมู']
# ['ถั่วลิสง']
# ['กระเทียม']
# ['ขิงซอย']
# ['ผง', 'ฮินเล']
# ['เส้น', 'ใหญ่']
# ['คะน้า']
# ['เห็ดนางรมหลวง']
# ['แครอท']
# ['เครื่อง', 'ผัด']
# ['ซีอิ้วขาว']
# ['คน', 'อร์หมู']
# ['เนื้อ', 'อก', 'ไก่']
# ['กระเทียม']
# ['ผักชี']
# ['พริกไทย']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['คน', 'อร์หมู']
# ['ไม้', 'เสียบ']
# ['ถั่วฝักยาว']
# ['แตงร้าน']
# ['แครอท']
# ['มะเขือเทศ', '2', 'สี']
# ['มะนาว']
# ['น้ำตาล']
# ['กระเทียม']
# ['พริกขี้หนู', 'แห้ง']
# ['หอยดอง']
# ['น้ำปลา']
# ['คน', 'อร์หมู']
# ['กุ้ง', 'ป่น']
# ['ผักชี']
# ['ผักชี']
# ['ขิงแก่']
# ['เหล้า', 'จีน', '(', '1', ')', 'สำหรับ', 'ต้ม']
# ['เอ็นหมู']
# ['ต้นหอม']
# ['กุ้ง']
# ['เห็ดหอม']
# ['กระเทียม']
# ['พริกไทย']
# ['ซอสเห็ด', 'หอม']
# ['ซีอิ้วขาว']
# ['คน', 'อร์หมู']
# ['ซีอิ้วขาว']
# ['น้ำมัน']
# ['วุ้น', 'เส้น', 'ห่อ', 'เล็ก']
# ['หนวด', 'หมึก']
# ['หอมแดง']
# ['ผักชี']
# ['ต้นหอม']
# ['มะนาว']
# ['ซีอิ้วขาว']
# ['ข้าว', 'คั่ว']
# ['พริกป่น']
# ['คน', 'อร์หมู']
# ['เต้าหู้อ่อน', ' ', '(', 'ทำ', 'เอง', ')']
# ['เห็ดหอม']
# ['น้ำ', 'สะอาด']
# ['คน', 'อร์เห็ด']
# ['ซีอิ๊ว', 'จีน']
# ['เหล้าจีน']
# ['น้ำมัน', 'งา']
# ['ขิงซอย']
# ['ต้นหอม']
# ['คึ่น', 'ไฉ่']
# ['ถั่วฝักยาว']
# ['น้ำพริก', 'แกง']
# ['กุ้ง', 'แห้ง']
# ['น้ำตาล']
# ['คน', 'อร์หมู']
# ['ซีอิ้วขาว']
# ['ใบ', 'มะกรูด', 'ซอย']
# ['ข้าว', 'สวย', 'แช่', 'เย็น']
# ['ไส้', 'กรอก']
# ['ไข่ไก่']
# ['แครอท', 'หั่น', 'เล็ก', 'ๆ']
# ['ถั่วฝักยาว', 'ซอย']
# ['ต้นหอมซอย']
# ['กระเทียม']
# ['คน', 'อร์หมู']
# ['ซีอิ้วขาว']
# ['พริกไทย']
# ['น้ำตาล']
# ['น้ำมัน']
# ['ถั่วงอก']
# ['เต้า', 'หู้อ่อน', '(', 'ทำ', 'เอง', ')']
# ['กุ้ยไช่']
# ['น้ำมัน']
# ['กระเทียม']
# ['คน', 'อร์เห็ด']
# ['ซีอิ้วขาว']
# ['ซ้อสเห็ดหอม']
# ['ไข่ไก่']
# ['แหนม', 'เห็ด']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'พืช']
# ['ข้าวโพดหวาน']
# ['ไข่', 'เค็ม']
# ['กุ้ง', 'แห้ง']
# ['มะเขือเทศ']
# ['มะเขือก', 'รอบ']
# ['พริกขี้หนู']
# ['กระเทียม']
# ['มะนาว']
# ['น้ำตาล']
# ['น้ำปลา']
# ['ถั่วลิสง']
# ['ผักเคียง', 'จาน']
# ['เห็ดนางรมหลวง']
# ['เห็ดหอม', 'สด']
# ['เห็ดหูหนู']
# ['กระเทียม']
# ['ข้าวหอมนิลสุก']
# ['ข้าวเหนียว', 'นึ่ง', 'สุก']
# ['เกลือ']
# ['พริกขี้หนูสวน']
# ['ถุง', 'พลาติก', 'และ', 'หนัง', 'ยาง']
# ['อัลมอนด์']
# ['น้ำ', 'สะอาด']
# ['กล้วย']
# ['นมอัลม่อนด์']
# ['โยเกิร์ต']
# ['น้ำตาล']
# ['น้ำ', 'แข็ง']
# ['น้ำตาล']
# ['บ๊วยดอง']
# ['น้ำ', 'สะอาด']
# ['เนื้อ', 'อก', 'เป็ดพะโล้']
# ['ขิงแก่ซอย']
# ['เห็ดหูหนู']
# ['กระเทียม']
# ['เต้าเจี้ยว']
# ['ซอสเห็ด', 'หอม']
# ['พริกไทย']
# ['พริกหยวก']
# ['เบคอน']
# ['กระเทียม']
# ['ซอสเห็ด', 'หอม']
# ['น้ำมัน', 'สำหรับ', 'ผัด']
# ['หมู', 'สับ']
# ['มะเขือยาว', 'ขั้ว', 'เล็ก']
# ['พริก', 'แกงเผ็ด']
# ['เนย']
# ['ซีอิ้วขาว']
# ['เกลือ']
# ['น้ำตาล']
# ['พริกชี้ฟ้า']
# ['ใบ', 'มะกรูด']
# ['ใบ', 'โหระพา']
# ['แผ่นเกี๊ยว']
# ['เห็ดหอม', 'สด']
# ['เห็ดนางรมหลวง']
# ['ข้าวโพด']
# ['แครอท']
# ['หอม', 'ใหญ่']
# ['ไข่ไก่']
# ['ผักชี']
# ['กระเทียม']
# ['พริกไทย']
# ['เกลือ']
# ['น้ำตาล']
# ['ใบ', 'กุยไช่']
# ['น้ำมัน', 'พืช']
# ['หมู', 'สับ']
# ['กะเพราบ้าน']
# ['พริกขี้หนู', 'หอม']
# ['พริกขี้หนู', 'แห้ง']
# ['กระเทียม']
# ['ซีอิ๊ว', 'ดำ', 'เค็ม']
# ['น้ำมัน', 'พืช']
# ['โยเกิร์ต']
# ['แครกเกอร์']
# ['น้ำตาล']
# ['ช้อตเทนนิ่ง', 'รำข้าว']
# ['น้ำมัน', 'มะพร้าว']
# ['พิมพ์', 'ถ้วย', 'นึ่ง', 'ข้าว']
# ['เม็ด', 'มะม่วงหิมพานต์']
# ['ชีส']
# ['เนย']
# ['น้ำตาล']
# ['น้ำ', 'เลม่อน']
# ['วานิลลา']
# ['ผิว', 'เลม่อน', 'ขูด']
# ['ผักคะน้า']
# ['กุ้ง']
# ['กระเทียม']
# ['ซอสเห็ด', 'หอม']
# ['แผ่นเมี่ยง', 'ญวน']
# ['ก้ามปู', 'หิมะ', 'เทียม']
# ['ผักสลัดเขียว']
# ['แดง', ' ', 'อย่าง', 'ละ']
# ['แครอทหั่นเส้น']
# ['แตงกวา', 'หั่นเส้น']
# ['มะเขือเทศ', 'หั่น', 'เส้น']
# ['ขนมปัง']
# ['ก้ามปู', 'หิมะ', 'เทียม']
# ['แครอทหั่นเส้น']
# ['แตงกวา', 'หั่นเส้น']
# ['มะเขือเทศ', 'หั่น', 'เส้น']
# ['ผักสลัด เขียว']
# ['แดง', ' ', 'อย่าง', 'ละ']
# ['กล้วย']
# ['ไข่ไก่']
# ['น้ำมัน', 'พืช']
# ['แป้งโฮล', 'วีท']
# ['น้ำตาล']
# ['เบคกิ้งโซดา']
# ['ผง', 'ฟู']
# ['วานิลลา']
# ['กล้วย']
# ['อัลมอนด์']
# ['หนังหมู']
# ['กังป๋วย']
# ['คน', 'อร์หมู']
# ['กระเทียม']
# ['ต้นหอม']
# ['คึ่น', 'ไช่']
# ['ซีอิ้วขาว']
# ['ฝรั่ง', 'ผล', 'เล็ก']
# ['ส้ม']
# ['แครอท']
# ['แตงกวา', 'อ่อน', 'ปอก', 'ผิว', 'แล้ว']
# ['ก้าม', 'กุ้ง']
# ['ซีอิ้วขาว']
# ['เกลือ']
# ['กระเทียม']
# ['สับปะะรด']
# ['น้ำตาล']
# ['เพ็กติน']
# ['มะนาว']
# ['เกลือ']
# ['หน่อไม้']
# ['หมู', 'สับ']
# ['กระเทียม']
# ['พริกขี้หนู', 'แห้ง']
# ['พริกชี้ฟ้า']
# ['ใบ', 'มะกรูด']
# ['คน', 'อร์หมู']
# ['หมู', 'สับ']
# ['เลือด', 'หมู']
# ['กระเพาะ', 'หมู']
# ['เต้า', 'หู้', 'ไข่']
# ['กระเทียม']
# ['คน', 'อร์ไก่']
# ['ซีออ๊วขาว']
# ['ต้น', 'หอม', '/', 'คึ่น', 'ไช่']
# ['กุนเชียง']
# ['แตงกวา']
# ['หอมแดง']
# ['พริกขี้หนูสวน']
# ['มะเขือเทศราชินี']
# ['มะนาว']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['ผักชี']
# ['กุ้ง']
# ['หลดบัว']
# ['กระเทียม']
# ['คน', 'อร์ไก่']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'สำหรับ', 'ผัด']
# ['หน่อไม้']
# ['อก', 'ไก่', 'สับ']
# ['กระเทียม']
# ['พริกขี้หนูสวน']
# ['พริกชี้ฟ้า']
# ['ใบ', 'โหระพา']
# ['ซีอิ้วขาว']
# ['ผักกาดดอง']
# ['กระเพาะ', 'หมู']
# ['ข่าแก่']
# ['พริกไทย']
# ['ผักชี']
# ['กระเทียม']
# ['เกลือ']
# ['ซีอิ้วขาว']
# ['น้ำ', 'สต๊อก']
# ['เห็ดโคนต้มสุก']
# ['ข่าแก่']
# ['ตะไคร้']
# ['ใบ', 'มะกรูด']
# ['พริกขี้หนู', 'สวน', ' ', 'สี', 'แดง']
# ['มะนาว']
# ['ซีอิ้วขาว']
# ['น้ำ', 'สต๊อก']
# ['ผักชี']
# ['ลูกเดือย']
# ['เผือก']
# ['น้ำตาล']
# ['แป้งมัน']
# ['น้ำ', 'สะอาด']
# ['เนย']
# ['แป้ง', 'ข้าวเจ้า']
# ['เกลือ']
# ['ไข่ไก่']
# ['ก้าม', 'กุ้ง']
# ['พริกไทย']
# ['ซ้อสถั่ว', 'เหลือง']
# ['น้ำมัน']
# ['กุ้ง']
# ['เห็ดนางรมหลวง']
# ['ตะไคร้']
# ['ใบ', 'มะกรูด']
# ['พริกขี้หนู', 'สวน', ' ', 'สี', 'แดง']
# ['น้ำ', 'มะนาว']
# ['ซีอิ้วขาว']
# ['น้ำ', 'สต๊อก']
# ['ข่าแก่']
# ['ปลาสลิด']
# ['พริก', 'แกงเผ็ด']
# ['เนย']
# ['พริกชี้ฟ้า']
# ['ใบ', 'มะกรูด']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['พริกจินดา', 'แห้ง']
# ['ตะไคร้', '/', 'ข่า', ' ', 'อย่าง', 'ละ']
# ['กะปิ']
# ['หอมแดง']
# ['กระเทียม']
# ['พริกไทย']
# ['เกลือ']
# ['เนื้อ', 'ไก่', 'สับ', '+', 'เครื่อง', 'ใน', '+', 'ขา']
# ['มะเขือเปราะ', ' ', '+', ' ', 'มะเขือเหลือง', ' ', 'อย่าง', 'ละ']
# ['มะเขือพวง']
# ['ถั่วฝักยาว']
# ['พริกชี้ฟ้า']
# ['ใบ', 'มะกรูด', '/', ' ', 'ใบ', 'กระเพรา']
# ['ซีอิ้วขาว']
# ['หอยดอง']
# ['ตะไคร้']
# ['หอมแดง']
# ['พริกขี้หนูสวน']
# ['ขิงซอย']
# ['ใบ', 'มะกรูด']
# ['ลูกชิ้น', 'ปลา']
# ['มะเขือเปราะ']
# ['กระชาย']
# ['ใบ', 'มะกรูด', '/', 'พริกชี้ฟ้า']
# ['ซอสเห็ด', 'หอม']
# ['พริกจินดาแดง']
# ['กระเทียม']
# ['เนื้อ', 'บวบ', 'หั่น', 'ชิ้น']
# ['ไข่ไก่']
# ['ซีอิ้วขาว']
# ['พริกไทย', 'ป่น']
# ['น้ำ', 'สต๊อก']
# ['เนื้อไก่']
# ['ขาไก่']
# ['เครื่อง', 'ใน', 'ไก่']
# ['พริกแกงแดง']
# ['พริกจินดาแดง']
# ['พริกขี้หนูสวน']
# ['พริกไทย']
# ['กระเทียม']
# ['ใบ', 'ยี่หร่า']
# ['พริกชี้ฟ้า', '/', 'ใบมะกรูด']
# ['ซีอิ้วขาว']
# ['เกลือ']
# ['น้ำมัน']
# ['กล้วย']
# ['น้ำตาล']
# ['น้ำ', 'สะอาด']
# ['ใบ', 'เตย']
# ['หมู', 'สาม', 'ชั้น']
# ['ซีอิ๊ว']
# ['น้ำมัน']
# ['สับปะรด', ' ', '1', ' ', 'หัว', ' ', 'ชั่ง', 'ทั้ง', 'เปลือก']
# ['กุ้ง', 'แห้ง']
# ['เนย']
# ['พริกแกง', 'คั่ว']
# ['เกลือ']
# ['น้ำตาล']
# ['น้ำ', 'มะขาม']
# ['พริกชี้ฟ้า', '/', 'ใบมะกรูด']
# ['เป็ดเจ']
# ['ข้าว', 'คั่ว']
# ['พริกป่น']
# ['ซีอิ้วขาว']
# ['น้ำ', 'มะนาว']
# ['น้ำตาล']
# ['ผักชี']
# ['ผักแพว', ' ', '(', ' ', 'ผักไผ่', ' ', ')']
# ['ใบ', 'สะระ', 'แหน่', 'สำหรับ', 'โรย', 'หน้า']
# ['ผักเคียง', 'จาน']
# ['ผักแกล้ม']
# ['ใบ', 'เหลียง']
# ['เห็ดโคน']
# ['พริกแดง']
# ['ซอสเห็ด', 'หอม']
# ['เห็ด', 'หอม', 'แห้ง']
# ['หัว', 'ไช่โป้ว']
# ['น้ำมัน', 'พืช']
# ['กะปิ']
# ['น้ำตาล']
# ['พริกขี้หนูสวน']
# ['มะอึก', ' ', 'ลูกเล็ก']
# ['มะนาว', 'ขนาด', 'กลาง']
# ['มะเขือพวง']
# ['สายบัว']
# ['เห็ดหอม']
# ['เนย']
# ['กะปิ']
# ['พริกไทย', 'เม็ด']
# ['น้ำตาล']
# ['น้ำ', 'มะขาม']
# ['เกลือ']
# ['พริกแดง']
# ['ยอด', 'ผักกระเฉด']
# ['ยอดชะอม']
# ['สะตอ']
# ['เต้าหู้', 'ขาว']
# ['วุ้นเส้น']
# ['พริกชี้ฟ้า']
# ['พริกแดงจินดา']
# ['ซอสเห็ด', 'หอม']
# ['ซีอิ้วขาว']
# ['หมี่เบตง']
# ['ถั่วงอก']
# ['แครอทฝอย']
# ['ฟอง', 'เต้า', 'หู้', 'ทอด', 'กรอบ']
# ['คื่นไฉ่']
# ['ซอสปรุงรส']
# ['เกลือ']
# ['เห็ดออรินจิ']
# ['พริกจินดาแดง']
# ['คึ่น', 'ไฉ่']
# ['เกลือ']
# ['น้ำตาล']
# ['หน่อไม้หวาน']
# ['เห็ดออรินจิ']
# ['เนื้อ', 'เป็ดเจ']
# ['ซอสเห็ด', 'หอม']
# ['ซีอิ้วขาว']
# ['พริกชี้ฟ้า']
# ['พริกแดงจินดา']
# ['ใบ', 'มะกรูด']
# ['กะหล่ำ']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'พืช']
# ['เป็ดเจ']
# ['ฟอง', 'เต้า', 'หู้', 'ทอด', 'กรอบ']
# ['หมี่กึง']
# ['เห็ดฟาง']
# ['ผง', 'ปรุง', 'รส', 'เห็ด', 'หอม']
# ['พริกไทย', 'ป่น', 'สำหรับ', 'โรย', 'หน้า']
# ['เส้น', 'ก๋วยจั๊บ']
# ['ผัก', 'ขึ้น', 'ฉ่าย', 'ซอย', 'สำหรับ', 'โรย', 'หน้า']
# ['เห็ดฟาง', ' ', '(', ' ', 'ซอย', 'หรือ', 'สับ', 'เป็น', 'ชิ้น', 'เล็ก', 'ๆ', ' ', ')']
# ['โปรตีน', 'เกษตร', ' ', '(', ' ', 'แช่', 'น้ำ', 'ให้', 'นุ่ม', ' ', ')']
# ['เต้า', 'หู้', 'ขาว', ' ', '(', ' ', 'บี้', 'ให้', 'แหลก', ' ', ')']
# ['พริกขี้หนู', ' ', 'เขียว', '-', 'แดง']
# ['ใบ', 'กะเพรา']
# ['ซอสเห็ด', 'หอม']
# ['ซีอิ๊ว', 'ดำ', 'เค็ม', ' ', '(', ' ', 'หรือ', 'ซอสปรุงรส', ' ', ')']
# ['กล้วย']
# ['แห้ว', 'ต้ม', ' ', '(', ' ', '4', ' ', 'หัว', ')']
# ['ถั่วทองต้มสุก']
# ['ลูก', 'เดือยต้มสุก']
# ['ฝรั่ง']
# ['สับปะรด']
# ['มะเขือเทศ']
# ['โยเกิร์ต']
# ['ขนมปัง']
# ['เต้า', 'หู้', 'ขาว', 'แข็ง']
# ['น้ำตาล']
# ['ซีอิ๊ว', 'ดำหวาน']
# ['เกลือ']
# ['โป้ย', 'กัก']
# ['อบเชย', 'ยาว', '1', '.', '5', 'นิ้ว']
# ['ผง', 'พะโล้']
# ['น้ำ', 'สะอาด']
# ['น้ำ', 'เต้า', 'หู้', 'ที่', 'ทำ', 'จาก', 'ถั่วเหลือง']
# ['ผงเจียะกอ', ' ', '(', '石', '膏', ')']
# ['น้ำ', 'สำหรับ', 'ละลายเจียะกอ']
# ['ก๋วยเตี๋ยว', 'เส้น', 'เล็ก']
# ['ถั่วงอก']
# ['หมู', 'สับ']
# ['กระเทียม']
# ['ซีอิ้วขาว']
# ['พริกป่น']
# ['ถั่วป่น']
# ['น้ำตาล']
# ['มะนาว']
# ['กุ้งฝอย']
# ['ผักชี']
# ['ผักกระเฉด']
# ['กระเทียม']
# ['พริกแดงจินดาซอย']
# ['ซอสเห็ด', 'หอม']
# ['น้ำมัน', 'พืช']
# ['โปรตีน']
# ['ผง', 'ปรุง', 'รส', 'เห็ด', 'หอม']
# ['น้ำตาล']
# ['หอมแดงซอย']
# ['น่องไก่', 'ขนาด', 'ใหญ่']
# ['เห็ดหอม']
# ['บ๊วยดอง', ' ', '(', ' ', 'ตัก', 'พร้อม', 'น้ำ', ' ', ')']
# ['ซีอิ้วขาว']
# ['สัน', 'ใน', 'ไก่']
# ['พริกแกงป่า']
# ['มะเขือเปราะ']
# ['มะเขือพวง']
# ['ซีอิ้วขาว']
# ['ใบ', 'มะกรูด']
# ['พริกชี้ฟ้า']
# ['ใบ', 'กะเพรา']
# ['อกไก่', ' ', '(', ' ', 'ลอกหนัง', 'ออก', ' ', ')']
# ['สะโพก', 'ไก่', ' ', '(', ' ', 'ลอกหนัง', 'ออก', ' ', ')']
# ['น้ำมัน']
# ['ซีอิ๊ว', 'ดำ', 'เค็ม']
# ['เนื้อ', 'อก', 'ไก่', 'สับ']
# ['เห็ดออรินจิซอย']
# ['แห้วซอย']
# ['แครอทซอย']
# ['ไข่ไก่']
# ['แป้ง', 'ข้าวโพด']
# ['ต้นหอมซอย', ' ', '(', 'ใช้', 'ช่วง', 'โคน', ')']
# ['เกลือ']
# ['น้ำตาล']
# ['พริกไทย', 'ป่น']
# ['ชวงเจียป่น', ' ', '(', 'พริกหอม', ')']
# ['ฟอง', 'เต้า', 'หู้', ' ', 'สำหรับ', 'ห่อ']
# ['เชือก', 'ปอ', ' ', 'สำหรับ', 'ผูก']
# ['ใบ', 'ตอง', ' ', 'สำหรับ', 'รอง', 'นึ่ง']
# ['ปีกไก่']
# ['น่อง', 'เล็ก', ' ', ')']
# ['แป้ง', 'ทอด', 'กรอบ']
# ['น้ำ', 'เย็น', 'จัด']
# ['ชาเขียว', 'มัชฉะ']
# ['เกล็ด', 'ขนมปัง']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['เนื้อ', 'อก', 'ไก่']
# ['น้ำตาล']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['เนื้อ', 'ไก่', 'น่อง', 'ติด', 'สะโพก', ' ', '1', ' ', 'ชิ้น']
# ['แป้ง', 'ข้าวโพด', '(', 'หรือ', 'แป้ง', 'อะไร', 'ก็ได้', ')']
# ['พริกแดงจินดา']
# ['กระเทียม']
# ['เกลือ']
# ['น้ำตาล']
# ['ซอสเห็ด', 'หอม']
# ['ต้นหอม']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['เนื้อ', 'อก', 'ไก่']
# ['หน่อไม้ดอง']
# ['พริกแดงจินดา']
# ['กระเทียม']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['ใบ', 'มะกรูด']
# ['พริกชี้ฟ้า']
# ['เนื้อ', 'อก', 'ไก่']
# ['ขิงซอย']
# ['เห็ดหูหนู']
# ['กระเทียม']
# ['ซอสเห็ด', 'หอม']
# ['น้ำตาล']
# ['อกไก่']
# ['กระเทียม']
# ['หอม', 'แดง', 'หัว', 'เล็ก']
# ['ผักชี']
# ['พริกไทย', 'เม็ด']
# ['น้ำตาล']
# ['ซอสปรุงรส']
# ['ใบ', 'ชะพลู']
# ['ตะไคร้', 'ต้น', 'เล็ก']
# ['ปลาส้ม']
# ['ปลาส้ม']
# ['ตะไคร้']
# ['หอมแดง']
# ['พริกขี้หนูสวน']
# ['ใบ', 'มะกรูด']
# ['น้ำ', 'ส้มเข้มข้น']
# ['น้ำ', 'มะนาว']
# ['ส้ม', 'ใน', 'น้ำ', 'เชื่อม']
# ['น้ำ', 'แข็ง']
# ['โซดา']
# ['แป้ง', 'เอนกประสงค์']
# ['แป่ง', 'ข้าวโพด']
# ['ผง', 'ฟู']
# ['ไข่ไก่']
# ['ไข่', 'ขาว']
# ['น้ำตาล']
# ['เกลือ']
# ['น้ำมัน', 'คาโนล่า']
# ['น้ำมันมะกอก']
# ['ซอยเกิร์ต', ' ', '1', ' ', 'ถ้วย', 'บรรจุ', 'ขาย']
# ['วานิลลา']
# ['สตรอว์เบอรี่', 'หั่น', 'ชิ้น', 'เล็ก']
# ['เหม่งสุ้น', ' ', '(', ' ', 'หน่อไม้จีน', ' ', ')', ' ', 'แห้ง']
# ['น้ำ', 'ซาว', 'ข้าว']
# ['เหม่งสุ้น', ' ', '(', ' ', 'หน่อไม้จีน', ' ', ')']
# ['เห็ดหอม']
# ['ผง', 'ปรุง', 'รส', 'เห็ด', 'หอม']
# ['ซีอิ้วขาว']
# ['กระเทียม']
# ['พริกไทย', 'ป่น', 'หยาบ']
# ['สะตอ']
# ['เห็ดนางรมหลวง']
# ['กะปิ']
# ['พริกจินดาแดง']
# ['กระเทียม']
# ['หอม', 'แดง', 'หัว', 'เล็ก']
# ['น้ำตาล']
# ['มะนาว']
# ['หมี่เตี๊ยว']
# ['ถั่วงอก']
# ['ต้น', 'กู๋', 'ไฉ่']
# ['ปลาหมึก']
# ['หอม', 'ใหญ่']
# ['กระเทียม']
# ['พริกไทย', 'ป่น']
# ['ซีอิ้วขาว']
# ['อกไก่', 'หั่น', 'ชิ้นบาง']
# ['พริก', 'แกงพะแนง']
# ['เนย']
# ['น้ำตาล']
# ['น้ำปลา']
# ['ใบ', 'มะกรูด', 'ซอย']
# ['พริกแดงซอย']
# ['ไส้อ่อน', 'ต้ม', 'สุก']
# ['ผักชี']
# ['กระเทียม']
# ['พริกไทย']
# ['ซีอิ้วขาว']
# ['ไม้', 'เสียบ']
# ['ไส้อ่อน']
# ['ใบ', 'ยี่หร่า']
# ['พริกแดงจินดา']
# ['กระเทียม']
# ['ซีอิ๊ว', 'ดำ', 'เค็ม']
# ['ถั่วเหลือง']
# ['น้ำ', 'สะอาด']
# ['เกลือ']
# ['เกลือ']
# ['ถั่วเหลือง']
# ['น้ำ', 'สะอาด']
# ['ไข่ไก่']
# ['น้ำตาล']
# ['เกลือ']
# ['แป้ง', 'เอนกประสงค์']
# ['ผง', 'ฟู']
# ['เบคกิ้งโซดา']
# ['เม็ด', 'มะม่วงหิมพานต์']
# ['น้ำมัน', 'คาโนล่า']
# ['วานิลลา']
# ['เม็ด', 'มะม่วงหิมพานต์']
# ['อินทผลัม']
# ['น้ำ', 'สะอาด']
# ['พริกจินดาแดง', ' ', '(', ' ', 'ตำ', ' ', ')']
# ['กระเทียม']
# ['หน่อไม้ดอง']
# ['เนื้อ', 'อก', 'ไก่']
# ['ซีอิ้วขาว']
# ['ผง', 'ปรุงรส']
# ['น้ำตาล']
# ['พริกแดง', ' ', '(', ' ', 'ซอย', ' ', ')']
# ['ใบ', 'มะกรูด', ' ', '(', ' ', 'ฉีก', ' ', ')']
# ['กู๋', 'ไฉ้', 'ก้วย']
# ['ไข่ไก่']
# ['น้ำมัน']
# ['ต้น', 'กู๋', 'ไฉ่']
# ['น้ำตาล']
# ['กระเทียม']
# ['เกลือ']
# ['เบคกิ้งโซดา']
# ['แป้ง', 'ข้าวเจ้า']
# ['แป้งมัน']
# ['น้ำ', 'สะอาด']
# ['น้ำจิ้ม']
# ['พริกดอง']
# ['น้ำเชื่อม']
# ['ซีอิ๊วหวาน']
# ['ซีอิ๊วเค็ม']
# ['ดอกอัญชัน']
# ['น้ำ', 'สะอาด']
# ['น้ำ', 'เชื่อม', 'เข้มข้น']
# ['น้ำ', 'มะนาว']
# ['โซดา']
# ['ปลาจาระเม็ด']
# ['ขิงอ่อนซอย']
# ['เห็ดหอมซอย']
# ['ต้น', 'หอม', ' ', 'ช่วง', 'หัว']
# ['บ๊วยดอง']
# ['กระเทียม']
# ['ซอสเห็ด', 'หอม']
# ['พริกไทย', 'ป่น']
# ['เหล้าจีน']
# ['พริกแดงซอย']
# ['หน่อไม้จีน', ' ', '(', ' ', 'เหม่งสุ้น', ' ', ')']
# ['กุ้ง']
# ['เห็ดหอม']
# ['ต้น', 'หอม', ' ', 'ช่วง', 'โคน']
# ['กระเทียม']
# ['ซีอิ้วขาว']
# ['พริกไทย', 'ป่น']
# ['น้ำมัน']
# ['ปลาตะเพียน']
# ['ตะไคร้']
# ['ใบ', 'มะกรูด']
# ['ข่าแก่']
# ['หอมแดง']
# ['พริก', 'แห้ง']
# ['แกน', 'สับปะรด']
# ['น้ำตาล']
# ['เกลือ']
# ['ซีอิ๊ว', 'ดำ', 'เค็ม']
# ['มะขามเปียก']
# ['เนย']
# ['เม็ด', 'ขนุน', 'ต้ม', 'สุก']
# ['น้ำตาล']
# ['เกลือ']
# ['ผักกาดขาว', 'ต้น']
# ['กระเทียม']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'พืช']
# ['ผักบุ้ง']
# ['กระเทียม']
# ['พริกขี้หนู']
# ['เต้าเจี้ยว']
# ['ซอสเห็ด', 'หอม']
# ['น้ำมัน', 'พืช']
# ['ไข่ไก่']
# ['คน', 'อร์หมู']
# ['น้ำ', 'สะอาด']
# ['ผักชี']
# ['สะตอ']
# ['กุ้ง']
# ['หมู', 'สับ']
# ['กระเทียม']
# ['หอมแดง']
# ['พริกจินดาแดง']
# ['คน', 'อร์หมู']
# ['น้ำมัน']
# ['กะปิ']
# ['หอยลาย']
# ['โหระพา']
# ['น้ำพริก', 'เผา']
# ['กระเทียม']
# ['พริกชี้ฟ้า']
# ['ซีอิ้วขาว']
# ['น้ำมัน']
# ['คอหมู']
# ['คน', 'อร์หมู']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['หน่อ', 'ใม้', 'สด']
# ['ใบ', 'ย่านาง']
# ['หอมแดง']
# ['ตะไคร้']
# ['กะปิ']
# ['น้ำตาล']
# ['เกลือ']
# ['ชะอม']
# ['ไข่ไก่']
# ['น้ำมัน', 'พืช']
# ['แมลงดานา']
# ['กะปิ']
# ['น้ำตาล']
# ['พริกขี้หนูสวน']
# ['กระเทียม']
# ['มะอึก', 'ลูก', 'ใหญ่']
# ['มะเขือพวง']
# ['มะนาว', 'ลูก', 'เล็ก']
# ['ผักไชยา', '(', 'เฉพาะ', 'ใบ', ')']
# ['ไข่ไก่']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'พืช']
# ['กระเทียม']
# ['หน่อไม้สดซอย']
# ['ไส้ตัน', '(', 'ฟอง', 'เต้า', 'หู้', ')']
# ['กระเทียม']
# ['พริกจินดาแดง']
# ['ซีอิ้วขาว']
# ['ใบ', 'กะเพรา']
# ['น้ำล้าง', 'ครก']
# ['น้ำมัน']
# ['คอหมู']
# ['กระเทียม']
# ['แป้ง', 'ข้าวโพด']
# ['พริกไทย', ' ', '(', ' ', 'ป่น', 'เอง', ' ', ')']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['มะพร้าว', 'ทึนทึก']
# ['น้ำตาล']
# ['ปลาทู']
# ['ชะอม']
# ['น้ำ', 'สต๊อก']
# ['น้ำมัน', 'พืช']
# ['พริกจินดาแดง']
# ['กระเทียม']
# ['ซีอ๊วขาว']
# ['ซอสเห็ด', 'หอม']
# ['กระเทียม']
# ['น้ำ', 'สะอาด']
# ['น้ำตาล']
# ['น้ำส้มสายชู']
# ['เกลือ']
# ['หน่อไม้']
# ['เกลือ']
# ['มะระ']
# ['เนื้อหมู']
# ['ผักกาดดอง']
# ['น้ำ', 'สต๊อก', 'เข้มข้น']
# ['เกลือ']
# ['ซีอิ้วขาว']
# ['ปู', 'เค็ม']
# ['มะม่วง', 'เปรี้ยว', 'ดิบ']
# ['หอมแดง']
# ['พริกขี้หนูสวน']
# ['น้ำตาล']
# ['กุ้ง']
# ['มะพร้าว', 'ขูด']
# ['พริกแกง']
# ['กระชาย']
# ['เกลือ']
# ['ซีอิ้วขาว']
# ['พริก', 'แห้ง']
# ['ตะไคร้']
# ['ข่า']
# ['ผิว', 'มะกรูด']
# ['หอมแดง']
# ['กระเทียม']
# ['กะปิ']
# ['กุ้ง']
# ['ต้นหอม']
# ['ขิงแก่']
# ['ผักชี']
# ['พริกไทย', 'ป่น', 'หยาบ']
# ['ซอสปรุงรส']
# ['น้ำมัน']
# ['กระเทียม']
# ['กุ้ง']
# ['กุ้ง']
# ['ใบ', 'กะเพรา']
# ['พริกขี้หนูสวน']
# ['พริกแดงจินดา']
# ['กระเทียม']
# ['ซอสปรุงรส']
# ['ซีอิ้วขาว']
# ['ขาไก่']
# ['ผักชี']
# ['กระเทียม']
# ['พริกไทย']
# ['พริกจินดา', 'แห้ง']
# ['เต้าซี่']
# ['พริกชี้ฟ้า', 'สด']
# ['น้ำ', 'สต๊อก']
# ['ซีอิ๊ว', 'ดำ', 'เค็ม']
# ['แอ๊ปเปิ้ล', 'เขียว', 'ลูก', 'เล็ก']
# ['น้ำ', 'แข็ง']
# ['น้ำเชื่อม']
# ['มะนาว']
# ['เกลือ']
# ['ไข่', 'มุก', 'ป๊อปรสลิ้นจี่']
# ['ส้มเขียวหวาน']
# ['แครอท', 'ยาว', '2', 'นิ้ว']
# ['มะเขือเทศ', 'สี', 'ดา']
# ['มะนาว']
# ['น้ำเชื่อม']
# ['เกลือ']
# ['น้ำ', 'แข็ง']
# ['มะม่วงดิบ']
# ['กะปิ']
# ['น้ำตาล']
# ['กระเทียม']
# ['หอมแดง']
# ['พริกขี้หนูสวน']
# ['เห็ดนางรมหลวง', ' ', '(', ' ', 'ออรินจิ', ' ', ')']
# ['ผักชี']
# ['ซีอิ้วขาว']
# ['ข้าว', 'คั่ว', '+', 'มะนาว']
# ['กระเทียม']
# ['มะนาว']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['พริกขี้หนูสวน']
# ['กระเทียม']
# ['พริกป่น']
# ['ข้าว', 'คั่ว']
# ['หอมแดง']
# ['ผักชี']
# ['หมู', 'สาม', 'ชั้น']
# ['หน่อไม้รวก']
# ['น้ำตาล']
# ['ซีอิ๊ว', 'ดำ', 'เค็ม']
# ['เกลือ']
# ['ผักชี']
# ['กระเทียม']
# ['พริกไทดำ']
# ['โป๊ยกัก']
# ['น้ำมัน', 'สำหรับ', 'ผัด']
# ['ปีกไก่']
# ['เกลือ']
# ['ปลาตะเพียน']
# ['เกลือ']
# ['กระเทียม']
# ['ข้าวเหนียว']
# ['ข้าว', 'สวย']
# ['ไส้ตัน', 'ฟอง', 'เต้า', 'หู้']
# ['กระเทียม']
# ['พริกไทย']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'พืช']
# ['ถั่วลิสง']
# ['น้ำผึ้ง']
# ['เกลือ']
# ['ถั่วแขก']
# ['หมู', 'สับ']
# ['พริกจินดาแดง', 'สับ']
# ['กระเทียม']
# ['เต้า', 'ซี่', 'สับ']
# ['น้ำมัน']
# ['เต้า', 'หู้อ่อน', '(', 'ทำ', 'เอง', ')']
# ['กระเทียม']
# ['พริกแดงจินดา']
# ['พริกขี้หนูสวน']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['เกลือ']
# ['น้ำตาล']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['ปลาหมึก']
# ['แครอทซอย']
# ['ต้น', 'หอม', 'หั่น', 'ท่อน']
# ['กระเทียม']
# ['ซี', 'อื๊ว', 'ขาว']
# ['ปลากราย']
# ['ถั่วฝักยาว', 'ซอย']
# ['พริกแกง', 'ใต้']
# ['ไข่ไก่']
# ['ใบ', 'มะกรูด', 'ซอย']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['ไส้', 'กรอก']
# ['เส้น', 'ขนม', 'จีน']
# ['มะเขือเทศ']
# ['ผักชี']
# ['ต้นหอม']
# ['ผักชี']
# ['หอมแดง']
# ['เห็ดออรินจิ']
# ['น้ำแจ่ว']
# ['แครอท']
# ['ตะไคร้']
# ['หอมแดง']
# ['ซีอิ้วขาว']
# ['พริกแดงจินดา']
# ['พริกขี้หนูสวน']
# ['เม็ด', 'มะม่วงหิมพานต์']
# ['เห็ดออรินจิ']
# ['แป้ง', 'ทอด', 'กรอบ']
# ['น้ำตาล']
# ['เพนเน่']
# ['เห็ดนางรมหลวง']
# ['เต้า', 'หู้', 'ขาว', 'ชิ้น', 'เล็ก']
# ['ถั่วฝักยาว']
# ['พริกจินดาแดง', '(', 'ซอย', ')']
# ['พริกขี้หนูสวน', '(', 'ตำ', ')']
# ['กระเทียม']
# ['ใบ', 'กะเพรา']
# ['ซีอิ้วขาว']
# ['เมล็ด', 'ท่น', 'ตะวัน']
# ['เกลือ']
# ['น้ำ', 'สะอาด']
# ['ข้าว', 'เย็น']
# ['ผักคะน้า']
# ['ไข่ไก่']
# ['แครอท']
# ['ซอสถั่วเหลือง']
# ['คน', 'อร์หมู']
# ['กระเทียม']
# ['พริกไทย']
# ['เนื้อหมู']
# ['น้ำปลา']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['แครกเกอร์']
# ['เนย']
# ['โยเกิร์ต']
# ['แยมบลูเบอร์รี่']
# ['ไข่ไก่']
# ['พริกขี้หนู']
# ['หัวหอมแดง']
# ['มะนาว']
# ['น้ำปลา']
# ['เห็ดเข็มทอง']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['ซีอิ๊วดำ']
# ['น้ำส้มสายชู']
# ['น้ำตาล']
# ['พริกขี้หนู']
# ['หมู', 'สับ']
# ['แผ่นเกี๊ยว']
# ['พริกไทย']
# ['กระเทียม']
# ['ผักชี']
# ['ซอสเห็ด', 'หอม']
# ['น้ำมัน', 'พืช']
# ['น้ำตาล']
# ['ปู', 'อัด']
# ['ไข่ไก่']
# ['พริกแกง']
# ['ใบ', 'มะกรูด']
# ['แป้ง', 'ชุบทอด']
# ['เกล็ด', 'ขนมปัง']
# ['อร่อย', 'ชัวร์']
# ['น้ำมัน', 'พืช']
# ['เห็ดออริจิ']
# ['แครอท']
# ['ต้นหอม']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['น้ำมัน', 'หอย']
# ['น้ำเปล่า']
# ['ตีนไก่']
# ['พริกแกง', 'คั่ว']
# ['ซีอิ้วขาว']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['พริกขี้หนู', 'สี', 'เขียว']
# ['ผักชี']
# ['ผักชี']
# ['กระเทียม']
# ['น้ำเปล่า']
# ['เกลือ']
# ['น้ำตาล']
# ['มะนาว']
# ['ขนมปัง']
# ['หมู', 'สับ']
# ['ไข่', 'ขาว']
# ['พริกไทย']
# ['คน', 'อร์ซอส']
# ['น้ำมัน', 'พืช']
# ['แป้งมัน']
# ['คะน้า']
# ['น้ำมัน', 'ถั่วเหลือง']
# ['คน', 'อร์ซอส']
# ['น้ำตาล']
# ['กระเทียม']
# ['น้ำเปล่า']
# ['เห็ดหอม']
# ['แครอท']
# ['กุ้ง']
# ['น้ำเปล่า']
# ['คน', 'อร์ซอส']
# ['น้ำตาล']
# ['ผักชี']
# ['พริกไทดำ']
# ['น้ำมัน', 'ถั่วเหลือง']
# ['หมู', 'สับ']
# ['ผักสามสี']
# ['เกลือ']
# ['พริกไทย']
# ['ไข่ไก่']
# ['แป้ง', 'ชุบทอด']
# ['เกล็ด', 'ขนมปัง']
# ['น้ำมัน', 'พืช']
# ['เห็ดออริจิ']
# ['น้ำมัน', 'ถั่วเหลือง']
# ['น้ำเปล่า']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['น้ำมัน', 'หอย']
# ['ไข่แดง']
# ['พริกขี้หนู']
# ['กระเทียม']
# ['หัวหอมแดง']
# ['น้ำปลา']
# ['น้ำตาล']
# ['มะนาว']
# ['ข้าว', 'สวย']
# ['ผักสามสี']
# ['โบโลน่า']
# ['ไข่ไก่']
# ['น้ำมัน', 'พืช']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['ไข่ไก่']
# ['ไข่แดง']
# ['น้ำมัน', 'พืช']
# ['หมู', 'เด้ง']
# ['ไข่แดง']
# ['ใบ', 'โหระพา']
# ['พริก', 'แกงเขียว', 'หวาน']
# ['คน', 'อร์ซอส']
# ['เนย']
# ['น้ำเปล่า']
# ['พริกชี้ฟ้า']
# ['มะเขือเปาะ']
# ['มะม่วงสุก']
# ['น้ำ', 'แข็ง']
# ['น้ำเชื่อม']
# ['เกลือ']
# ['มะนาว']
# ['น้ำเปล่า']
# ['ลูก', 'ชิ้น']
# ['พริกแกง']
# ['ข้าวโพดอ่อน']
# ['น้ำมัน', 'พืช']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['น้ำเปล่า']
# ['ข้าวหอมมะลิ']
# ['น้ำพริก', 'หรือ', 'น้ำ', 'จิ้ม', ' ', '(', 'ตาม', 'ชอบ', ')']
# ['สาหร่าย']
# ['แครอท']
# ['แตงกวา']
# ['หมู', 'ย่าง']
# ['วุ้นเส้น', 'สด']
# ['หมูยอ']
# ['น้ำเปล่า']
# ['ต้นหอม']
# ['ผักชี']
# ['หัวหอมแดง']
# ['ผง', 'ปรุง', 'รสร', 'สลาบ']
# ['ข้าว', 'คั่ว']
# ['หมู', 'เด้ง']
# ['เห็ดออรินจิ']
# ['น้ำเปล่า']
# ['คน', 'อร์ซอส']
# ['หัวหอมแดง']
# ['ตะไคร้']
# ['ใบ', 'มะกรูด']
# ['เกลือ']
# ['น้ำปลา']
# ['มะนาว']
# ['พริกป่น']
# ['ไข่ไก่']
# ['น้ำปลา']
# ['น้ำมัน', 'พืช']
# ['หมู', 'สับ']
# ['ตับหมู']
# ['ต้นหอม']
# ['ผักชี']
# ['หัวหอมแดง']
# ['ผง', 'ปรุง', 'รสร', 'สลาบ']
# ['น้ำเปล่า']
# ['ลูกชิ้น', 'หมู']
# ['แป้ง', 'ชุบทอด']
# ['น้ำเย็น']
# ['เกล็ด', 'ขนมปัง']
# ['น้ำมัน', 'พืช']
# ['พริก', 'แกงเขียว', 'หวาน']
# ['เนย']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['น้ำเปล่า']
# ['พริกชี้ฟ้า']
# ['ไข่', 'เค็ม']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['ผักบุ้ง']
# ['ผักกาดขาว']
# ['ขึ้น', 'ฉ่าย']
# ['เนื้อหมู']
# ['ลูก', 'ชิ้น']
# ['ซอสสุกี้']
# ['คน', 'อร์ซอส']
# ['ไข่ไก่']
# ['น้ำเปล่า']
# ['ผักสามสี']
# ['หมูสไลด์']
# ['ไข่ไก่']
# ['ซอสมะเขือเทศ']
# ['เกลือ']
# ['พริกไทย']
# ['ขนม', 'รัง', 'ผึ้ง']
# ['เบคอน']
# ['ไข่ไก่']
# ['น้ำผึ้ง']
# ['เนื้อหมู']
# ['พริกขี้หนู']
# ['เกลือ']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['เห็ดหิมะ', 'ขาว']
# ['แป้ง', 'ชุบทอด']
# ['น้ำเย็น']
# ['น้ำมัน', 'พืช']
# ['มา', 'ยองเนส']
# ['ไข่', 'กุ้ง']
# ['วาซาบิ']
# ['เห็ดหอม']
# ['หมู', 'สับ']
# ['ไข่แดง']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['ต้นหอม']
# ['แครอท']
# ['พริกไทย']
# ['เส้น', 'ยากิโซบะ']
# ['เนื้อหมู']
# ['กะหล่ำ']
# ['ผักกาดแก้ว']
# ['แครอท']
# ['ต้นหอม']
# ['ซอสทาคูมิ']
# ['น้ำเชื่อม']
# ['น้ำมัน', 'พืช']
# ['กีวี่แช่ฟรีซ']
# ['น้ำ', 'แข็ง']
# ['มะนาว']
# ['น้ำเชื่อม']
# ['เกลือ']
# ['ถั่วงอก']
# ['แครอท']
# ['ต้มหอม']
# ['หมู', 'สับ']
# ['เต้า', 'หู้']
# ['น้ำเปล่า']
# ['อร่อย', 'ชัวร์']
# ['น้ำตาล']
# ['น้ำมัน', 'หอย']
# ['พริกไทย']
# ['เต้า', 'หู้', 'ไข่']
# ['แครอท']
# ['ผักกาดขาว']
# ['เห็ดชิเมจิ']
# ['คะน้าฮ่องกง']
# ['น้ำเปล่า']
# ['น้ำมัน', 'พืช']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['น้ำมัน', 'หอย']
# ['พริกขี้หนู']
# ['หมู', 'สับ']
# ['ผง', 'ปรุง', 'รสร', 'สลาบ']
# ['น้ำมัน', 'พืช']
# ['ผักตาม', 'ชอบ']
# ['หมูยอ']
# ['ไข่แดง']
# ['ขึ้น', 'ฉ่าย']
# ['หัวหอมแดง']
# ['พริกขี้หนู']
# ['น้ำปลา']
# ['มะนาว']
# ['น้ำตาล']
# ['ไข่ไก่']
# ['น้ำเปล่า']
# ['คน', 'อร์ซอส']
# ['เกลือ']
# ['เต้า', 'หู้', 'ไข่']
# ['พริกไทดำ']
# ['ต้มหอม']
# ['ผักชี']
# ['น้ำมัน', 'พืช']
# ['เนื้อหมู']
# ['อร่อย', 'ชัวร์']
# ['น้ำมัน', 'หอย']
# ['เนย']
# ['พริกขี้หนู']
# ['กระเทียม']
# ['น้ำเปล่า']
# ['น้ำตาล']
# ['ใบ', 'มะกรูด']
# ['เห็ดเข็มทอง']
# ['ข้าวโพดอ่อน']
# ['แครอท']
# ['น้ำมัน', 'พืช']
# ['น้ำเปล่า']
# ['อร่อย', 'ชัวร์']
# ['น้ำตาล']
# ['ต้นหอม']
# ['ซอสหอยนางรม']
# ['น้ำพริก', 'เผา']
# ['ปลาดุก']
# ['ใบยอ']
# ['พริกแกง']
# ['เนย']
# ['น้ำเปล่า']
# ['น้ำตาล']
# ['คน', 'อร์ซอส']
# ['น้ำปลา']
# ['เห็ดเข็มทอง']
# ['หมูสไลด์']
# ['เนย']
# ['กระเทียม']
# ['พริกขี้หนู']
# ['น้ำตาล']
# ['น้ำเชื่อม']
# ['เกลือ']
# ['มะนาว']
# ['ผักชี']
# ['ผักชี']
# ['กาก', 'หมู']
# ['พริกป่น']
# ['อร่อย', 'ชัวร์']
# ['ตับหมู']
# ['ผักชี']
# ['กระเทียม']
# ['พริกไทย']
# ['นมสด']
# ['น้ำตาล']
# ['เกลือ']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'พืช']
# ['ข้าว', 'สวย']
# ['ต้นหอม']
# ['แครอท']
# ['ไข่ไก่']
# ['ขนมพริก']
# ['เนย']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['อกไก่']
# ['แครอท']
# ['เห็ดหอม']
# ['น้ำเปล่า']
# ['ผัด', 'กาดขาว']
# ['คน', 'อร์ซอส']
# ['เกลือ']
# ['พริกไทดำ']
# ['ต้มหอม']
# ['ผักชี']
# ['ไข่ไก่']
# ['ใบ', 'มะกรูด']
# ['พริกแกง']
# ['น้ำปลา']
# ['น้ำตาล']
# ['เนย']
# ['เกี๊ยว', 'แผ่น']
# ['น้ำมัน', 'พืช']
# ['มา', 'ยองเนส']
# ['ซอสพริก']
# ['วาซาบิ']
# ['ปูม้า']
# ['พริกขี้หนู']
# ['ใบ', 'มะกรูด']
# ['พริกแกง', 'คั่ว']
# ['เนย']
# ['น้ำเปล่า']
# ['คน', 'อร์ซอส']
# ['น้ำตาล']
# ['น้ำมัน', 'พืช']
# ['เต้าหู้', 'ขาว']
# ['พริกขี้หนู']
# ['เกลือ']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['ข้าว', 'สวย']
# ['เนื้อหมู']
# ['แป้ง', 'ชุบทอด']
# ['ไข่ไก่']
# ['เกล็ด', 'ขนมปัง']
# ['น้ำมัน', 'พืช']
# ['เนย']
# ['พริก', 'แกงเขียว', 'หวาน']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['แครอท']
# ['ใบ', 'โหระพา']
# ['น้ำเปล่า']
# ['ไข่ไก่']
# ['น้ำมัน', 'พืช']
# ['น้ำเปล่า']
# ['คน', 'อร์ซอส']
# ['เกลือ']
# ['น้ำพริก', 'เผา']
# ['มะนาว']
# ['เห็ดหูหนู']
# ['วุ้นเส้น']
# ['แครอท']
# ['ต้นหอม']
# ['ผักชี']
# ['พริกป่น']
# ['หมูยอ']
# ['แครอท']
# ['หัวหอม', 'ใหญ่']
# ['กะหล่ำ']
# ['น้ำเปล่า']
# ['น้ำปลา']
# ['น้ำเชื่อม']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['เต้าหู้', 'ขาว']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['เกลือ']
# ['ข้าว', 'สวย', ' ', 'หรือ', ' ', 'ข้าวญี่ปุ่น']
# ['หมูสไลด์']
# ['หัวหอม', 'ใหญ่']
# ['ทาคูมิ']
# ['น้ำตาล']
# ['น้ำเปล่า']
# ['ต้นหอม']
# ['ไข่ไก่']
# ['น้ำมัน', 'พืช']
# ['คน', 'อร์ซอส']
# ['ผักกาดขาว']
# ['อกไก่']
# ['เกลือ']
# ['พริกไทย']
# ['แครอท']
# ['เห็ดหอม']
# ['น้ำเปล่า']
# ['น้ำ', 'จิ้มสุกี้']
# ['อกไก่']
# ['แป้ง', 'ชุบ', 'ทอด', 'รส', 'เผ็ด']
# ['น้ำเย็น']
# ['น้ำมัน', 'พืช']
# ['แครอท']
# ['สับปะรด']
# ['หัวหอม', 'ใหญ่']
# ['เกลือ']
# ['ซอสพริก']
# ['ซอสมะเขือเทศ']
# ['น้ำส้มสายชู']
# ['น้ำตาล']
# ['หมู']
# ['พริกแกง', 'คั่ว']
# ['เนย']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['ผักบุ้งจีน']
# ['กุนเชียง']
# ['ข้าว', 'สวย']
# ['น้ำมัน', 'พืช']
# ['ถั่ว', 'ลิลง', 'บด']
# ['ขนมปัง']
# ['ปู', 'อัด']
# ['มา', 'ยองเนส']
# ['พริกไทดำ']
# ['ไข่ไก่']
# ['พริกหวาน', 'สี', 'แดง']
# ['ต้นหอม']
# ['แครอท']
# ['เกลือ']
# ['พริกไทย']
# ['เนย']
# ['ไข่', 'กุ้ง']
# ['มา', 'ยองเนส']
# ['เต้า', 'เจี้ยว', 'สำหรับ', 'หลน']
# ['น้ำเปล่า']
# ['เนย']
# ['หัวหอมแดง']
# ['หมู', 'สับ']
# ['ไข่ไก่']
# ['น้ำตาล']
# ['พริกขี้หนู']
# ['ผักชี']
# ['เต้า', 'หู้', 'ไข่']
# ['หมู', 'สับ']
# ['พริกขี้หนู']
# ['ใบ', 'กะเพรา']
# ['น้ำมัน', 'พืช']
# ['น้ำเปล่า']
# ['อร่อย', 'ชัวร์']
# ['น้ำตาล']
# ['ผง', 'กะเพรา']
# ['เนื้อหมู']
# ['ผง', 'ปรุงรส', 'หมู']
# ['เนย']
# ['พริกแกง', 'คั่ว']
# ['ถั่วลิสง']
# ['แตงกวา']
# ['หัวหอมแดง']
# ['พริกขี้หนู']
# ['น้ำเชื่อม']
# ['น้ำส้มสายชู']
# ['น้ำเปล่า']
# ['เกลือ']
# ['น้ำมัน', 'พืช']
# ['ข้าว', 'สวย']
# ['ปลาส้ม']
# ['ตะไคร้']
# ['ใบ', 'มะกรูด']
# ['น้ำพริกสูตร', 'คุณ', 'ยาย']
# ['น้ำมัน', 'พืช']
# ['อร่อย', 'ชัวร์']
# ['ผักกาดหอม']
# ['หัวหอม', 'ใหญ่']
# ['มะเขือเทศ']
# ['คอหมู']
# ['เกลือ']
# ['พริกไทย']
# ['เนย']
# ['น้ำส้มสายชู']
# ['น้ำเชื่อม']
# ['คอหมู']
# ['เนย']
# ['พริกแกงแดง']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['ใบ', 'มะกรูด']
# ['เนย']
# ['ปลา', 'ช่อน']
# ['พริกขี้หนู']
# ['น้ำมัน', 'พืช']
# ['ข้าว', 'สวย']
# ['ไข่ไก่']
# ['น้ำเปล่า']
# ['น้ำ', 'ส้ม']
# ['น้ำ', 'หวาน', 'กลิ่นสละ']
# ['โซดา']
# ['มะนาว']
# ['น้ำ', 'แข็ง']
# ['เนื้อหมู']
# ['แป้ง', 'ชุบทอด']
# ['อร่อย', 'ชัวร์']
# ['พริกป่น']
# ['น้ำมัน', 'พืช']
# ['คอหมู']
# ['เนย']
# ['พริกแกง']
# ['อร่อย', 'ชัวร์']
# ['น้ำตาล']
# ['น้ำเปล่า']
# ['มะเขือเทศ']
# ['ใบ', 'มะกรูด']
# ['พริกชี้ฟ้า']
# ['อกไก่']
# ['เกลือ']
# ['พริกไทดำ']
# ['ออริกาโน่']
# ['ปาปริก้า']
# ['น้ำมัน', 'พืช']
# ['แป้ง', 'ชุบทอด']
# ['โซดา']
# ['ไข่ไก่']
# ['ปลาหมึก']
# ['พริกแกงแดง']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['ใบ', 'มะกรูด']
# ['น้ำมัน', 'พืช']
# ['ปลาหมึก']
# ['หมู', 'สับ']
# ['กระเทียม']
# ['น้ำมัน', 'พืช']
# ['พริกไทดำ']
# ['อร่อย', 'ชัวร์']
# ['ไก่', 'บ้าน']
# ['พริกแกง']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['ลูกพริกไทย']
# ['กระชาย']
# ['พริกชี้ฟ้า']
# ['น้ำมัน', 'พืช']
# ['น้ำเปล่า']
# ['อร่อย', 'ชัวร์']
# ['ไข่ไก่']
# ['กุ้ง']
# ['ปู', 'อัด']
# ['น้ำเปล่า']
# ['เครื่อง', 'ต้มยำ']
# ['น้ำพริก', 'เผา']
# ['น้ำปลา']
# ['มะนาว']
# ['นมจืด']
# ['พริกขี้หนู']
# ['หมู', 'สาม', 'ชั้น']
# ['อร่อย', 'ชัวร์']
# ['น้ำมัน', 'หอย']
# ['น้ำพริก', 'เผา']
# ['นมข้น', 'จืด']
# ['น้ำเปล่า']
# ['แป้ง', 'ชุบทอด']
# ['พริกไทดำ']
# ['น้ำมัน', 'พืช']
# ['หมู', 'แผ่น']
# ['หนัง', 'ไก่', 'กรอบ']
# ['เม็ด', 'มะม่วงหิมพานต์']
# ['หัวหอม', 'ใหญ่']
# ['ขึ้น', 'ฉ่าย']
# ['พริกขี้หนู']
# ['น้ำปลา']
# ['มะนาว']
# ['น้ำเชื่อม']
# ['น้ำเปล่า']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['หมู', 'สับ']
# ['พริกขี้หนู']
# ['ผง', 'กะเพรา']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['น้ำมัน', 'หอย']
# ['น้ำเปล่า']
# ['ใบ', 'กะเพรา']
# ['น้ำมัน', 'พืช']
# ['ไข่ไก่']
# ['ข้าว', 'สวย', ' ', 'หรือ', ' ', 'ข้าวญี่ปุ่น']
# ['ไข่ไก่']
# ['พริกไทย']
# ['เนย']
# ['หมู', 'สับ']
# ['ทาคูมิ']
# ['น้ำเชื่อม']
# ['ต้มหอม']
# ['น้ำเปล่า']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['ปลากระป๋อง']
# ['น้ำเปล่า']
# ['น้ำปลา']
# ['มะนาว']
# ['พริกป่น']
# ['ตะไคร้']
# ['ใบ', 'มะกรูด']
# ['ผักชี']
# ['อกไก่']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['สาหร่าย']
# ['ทาคูมิ']
# ['น้ำเชื่อม']
# ['น้ำเย็น']
# ['หมู', 'สับ']
# ['กระเทียม']
# ['พริกขี้หนู']
# ['น้ำมัน', 'พืช']
# ['กะเพรา']
# ['น้ำปลา']
# ['น้ำตาล']
# ['น้ำมัน', 'หอย']
# ['น้ำเปล่า']
# ['เห็ด', 'นางฟ้า']
# ['ขึ้น', 'ฉ่าย']
# ['กระเทียม']
# ['น้ำมัน', 'พืช']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['พริกไทดำ']
# ['ไข่ไก่']
# ['เนื้อหมู']
# ['กระเทียม']
# ['เครื่อง', 'พะโล้']
# ['ผักชี']
# ['ผักชี']
# ['น้ำมัน', 'พืช']
# ['น้ำเปล่า']
# ['น้ำตาล']
# ['น้ำปลา']
# ['แครอท']
# ['ไข่ไก่']
# ['หมู']
# ['น้ำเปล่า']
# ['กระเทียม']
# ['พริกขี้หนู']
# ['น้ำปลา']
# ['มะนาว']
# ['น้ำเชื่อม']
# ['ผักชี']
# ['คะน้า']
# ['ขนมปัง']
# ['หมูหยอง']
# ['น้ำพริก', 'เผา']
# ['ผักตาม', 'ชอบ']
# ['มา', 'ยองเนส']
# ['เนื้อหมู']
# ['พริกไทดำ']
# ['เกลือ']
# ['ออริกาโน่']
# ['นมข้น', 'จืด']
# ['ขนมปัง']
# ['มา', 'ยองเนส']
# ['ซอสพริก']
# ['โบโลน่า']
# ['ไข่ไก่']
# ['นมข้น', 'จืด']
# ['เนย']
# ['ผักตาม', 'ชอบ']
# ['เกลือ']
# ['พริกไทย']
# ['อกไก่']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['พริกไทย']
# ['เกลือ']
# ['ข้าว', 'สวย']
# ['อกไก่']
# ['ไข่ไก่']
# ['มะเขือเทศ']
# ['ผักตาม', 'ชอบ']
# ['พริกไทย']
# ['ซอสพริก']
# ['น้ำเชื่อม']
# ['ทาคูมิ']
# ['เนย']
# ['กล้วย']
# ['นมสด']
# ['ไข่ไก่']
# ['เนย']
# ['กุนเชียง']
# ['โบโลน่า']
# ['หมู', 'สับ']
# ['ต้มหอม']
# ['พริกไทย']
# ['บะหมี่']
# ['น้ำเปล่า']
# ['กระเทียม']
# ['อกไก่']
# ['แป้งมัน']
# ['อร่อย', 'ชัวร์']
# ['น้ำตาล']
# ['ซีอิ๊วดำ']
# ['พริกไทย']
# ['พริกขี้หนู']
# ['ผักชี']
# ['ข้าว', 'สวย']
# ['ไส้', 'กรอก']
# ['ไข่ไก่']
# ['อกไก่']
# ['แครอท']
# ['ข้าวโพด']
# ['ผักคลอส']
# ['มา', 'ยองเนส']
# ['พริกไทดำ']
# ['เกลือ']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['ซอสมะเขือเทศ']
# ['ข้าวโพดต้ม']
# ['มา', 'ยองเนส']
# ['เนย']
# ['ซอสพริก']
# ['พริกไทดำ']
# ['ออริกาโน่']
# ['เกลือ']
# ['ข้าวโพด']
# ['น้ำตาล']
# ['เนย']
# ['เกลือ']
# ['นมข้น', 'จืด']
# ['หมูยอ']
# ['น้ำเปล่า']
# ['ข่า']
# ['ตะไคร้']
# ['ใบ', 'มะกรูด']
# ['คน', 'อร์ซอส']
# ['หอมแดง']
# ['ผักชี']
# ['น้ำปลา']
# ['มะนาว']
# ['พริกป่น']
# ['ข้าว', 'คั่ว']
# ['ผักชี']
# ['ไวไว']
# ['ลูกชิ้น', 'ปลา']
# ['คะน้า']
# ['ไข่ไก่']
# ['น้ำเปล่า']
# ['คน', 'อร์ซอส']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['พริกไทย']
# ['แป้งมัน']
# ['ข้าว', 'สวย']
# ['โบโลน่า']
# ['พริกหวาน', 'สี', 'แดง']
# ['พริกหวาน', 'สี', 'เหลือง']
# ['แครอท']
# ['กะหล่ำ']
# ['ต้นหอม']
# ['น้ำมัน', 'พืช']
# ['ไข่ไก่']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['วุ้นเส้น', 'สด']
# ['ไข่ไก่']
# ['ถั่วงอก']
# ['กะหล่ำ']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'พืช']
# ['ปลาตะเพียน']
# ['เกลือ']
# ['ข้าวเหนียว', 'นึ่ง']
# ['กระเทียม']
# ['ข้าว', 'สวย']
# ['แครอท']
# ['มะละกอ']
# ['เห็ดหอม']
# ['ต้นหอม']
# ['พริกหวาน', 'สี', 'เหลือง']
# ['หมู', 'สับ']
# ['เกลือ']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['ซีอิ๊วดำ']
# ['โคชูจัง']
# ['น้ำเชื่อม']
# ['น้ำ', 'ร้อน']
# ['อกไก่']
# ['น้ำมัน', 'พืช']
# ['แครอท']
# ['หัวหอม', 'ใหญ่']
# ['ต้นหอม']
# ['พริกไทดำ']
# ['น้ำเปล่า']
# ['ข้าว', 'สวย']
# ['กะปิ']
# ['พริกขี้หนู']
# ['กระเทียม']
# ['ผักชี']
# ['ใบ', 'มะกรูด']
# ['น้ำเปล่า']
# ['น้ำตาล']
# ['อร่อย', 'ชัวร์']
# ['น้ำมัน', 'พืช']
# ['เนื้อหมู']
# ['เกลือ']
# ['บะหมี่']
# ['น้ำเปล่า']
# ['ถั่วงอก']
# ['กระเทียม']
# ['เนื้อหมู']
# ['ลูก', 'ชิ้น']
# ['ต้นหอม']
# ['ผักชี']
# ['ถั่วลิสง']
# ['พริกป่น']
# ['น้ำปลา']
# ['น้ำส้มสายชู']
# ['น้ำตาล']
# ['เสาวรส']
# ['น้ำ', 'แข็ง']
# ['น้ำผึ้ง']
# ['น้ำเปล่า']
# ['เกลือ']
# ['ใบ', 'สะระ', 'แหน่']
# ['นมจืด']
# ['นม', 'ข้นหวาน']
# ['น้ำ', 'แข็ง']
# ['ช็อกโกแลต']
# ['เนื้อหมู']
# ['เกลือ']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['ไข่', 'ขาว']
# ['โกโก้']
# ['ไอซิ่ง']
# ['เนย']
# ['ขนมปัง']
# ['เนย']
# ['แยมบลูเบอร์รี่']
# ['แผ่นเกี๊ยว']
# ['หมู', 'สับ']
# ['แครอท']
# ['เห็ดหอม']
# ['ต้นหอม']
# ['น้ำเปล่า']
# ['คน', 'อร์ซอส']
# ['พริกไทดำ']
# ['ซีอิ้วขาว']
# ['ผักชี']
# ['อกไก่']
# ['เกลือ']
# ['พริกไทย']
# ['ซอสพริก']
# ['มา', 'ยองเนส']
# ['ออริกาโน่']
# ['ไข่ไก่']
# ['น้ำปลา']
# ['น้ำตาล']
# ['น้ำเปล่า']
# ['พริกขี้หนู']
# ['กระเทียม']
# ['เนื้อหมู']
# ['น้ำปลา']
# ['พริกป่น']
# ['แป้ง', 'ชุบทอด']
# ['น้ำมัน', 'พืช']
# ['ขนมปัง']
# ['เนย']
# ['ไอซิ่ง']
# ['ไข่ไก่']
# ['น้ำเปล่า']
# ['เนื้อหมู']
# ['หัวหอม', 'ใหญ่']
# ['น้ำมัน', 'ถั่วเหลือง']
# ['น้ำเปล่า']
# ['ทาคูมิ']
# ['น้ำตาล']
# ['กระเทียม']
# ...
# ['น้ำ', 'แข็ง']
# ['น้ำ', 'สะอาด']
# ['มะเขือเทศ']
# ['เกลือ']
# ['น้ำ', 'แข็ง']
# ['น้ำ', 'สะอาด']
# ['น้ำมัน']
# ['กระเทียม']
# ['เนื้อหมู']
# ['หอม', 'ใหญ่']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'หอย']
# ['พริกหยวก']
# ['น้ำ', 'สะอาด']
# ['ตะไคร้']
# ['ใบ', 'มะกรูด']
# ['หอมแดง']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['มะนาว']
# ['พริกเผา']
# ['เก็ดนางฟ้า']
# ['กุ้ง']
# ['นมจืด']
# ['ผักชี']
# ['พริกคั่ว']
# ['พริกขี้หนูตำ']
# ['น้ำมัน']
# ['กุ้ง']
# ['ไข่', 'เป็ด']
# ['หอม', 'ใหญ่']
# ['ข้าว', 'สวย']
# ['แครอท']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'หอย']
# ['พริกไทย', 'ป่น']
# ['มะเขือเทศ']
# ['ผักชี']
# ['ต้นหอมซอย']
# ['กุ้งก้ามกราม']
# ['น้ำ', 'จิ้ม', 'ซี', 'ฟู้ด']
# ['ถ่าน']
# ['กระเทียม']
# ['น้ำมัน']
# ['อกไก่']
# ['หอม', 'ใหญ่']
# ['ซอสปรุงรส']
# ['ไข่', 'เป็ด']
# ['ต้นหอมซอย']
# ['กระเทียม']
# ['ขิงซอย']
# ['หอม', 'ใหญ่ซอย']
# ['อกไก่']
# ['น้ำ', 'สะอาด']
# ['น้ำตาล']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'หอย']
# ['เต้าเจี้ยว']
# ['ซีอิ้ว', 'ดำ']
# ['เห็ดหู', 'หนูดำ']
# ['ตั้ง', 'โอ๋', 'หั่น', 'ท่อน']
# ['ต้น', 'หอม', 'หั่น', 'ท่อน']
# ['พริกใหญ่']
# ['น้ำมัน']
# ['หมู', 'สับ']
# ['เต้า', 'หู้', 'หั่น', 'เต๋า', 'ทอด']
# ['เส้นจันท์']
# ['ถั่วงอก']
# ['ต้นหอม']
# ['กระเทียม']
# ['อกไก่']
# ['บร็อคโคลี่']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'หอย']
# ['น้ำสต็อก']
# ['น้ำมัน']
# ['กระเทียม']
# ['พริกแห้งตำ']
# ['พริกขี้หนูตำ']
# ['พวงไข่']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['น้ำมัน', 'หอย']
# ['ใบ', 'กระเพรา']
# ['น้ำ', 'สะอาด']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซอสปรุงรส']
# ['พริกไทย', 'ป่น']
# ['เกลือ']
# ['ผักชี']
# ['เครื่อง', 'ตุ๋น', 'ยา', 'จีน']
# ['กระดูก', 'หมู']
# ['เห็ดหอม']
# ['เส้น', 'หมี่', 'ข้าว', 'กล้อง']
# ['น้ำ', 'ซุป']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'หอย']
# ['เต้าเจี้ยว']
# ['พริกไทย', 'ป่น']
# ['เนื้อหมู']
# ['คะน้า']
# ['แครอท']
# ['กะหล่ำ']
# ['ข้าวโพดอ่อน']
# ['เต้า', 'หู้', 'ปลา']
# ['แป้งมัน']
# ['แป้ง', 'ข้าวโพด']
# ['กระเทียม']
# ['น้ำ', 'สะอาด']
# ['พริก', 'แกงเผ็ด']
# ['อกไก่']
# ['ถั่วพู']
# ['แครอท']
# ['ข้าวโพดอ่อน']
# ['น้ำตาล']
# ['น้ำปลา']
# ['น้ำมัน', 'หอย']
# ['น้ำ', 'สะอาด']
# ['อกไก่']
# ['น้ำตาล']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'หอย']
# ['น้ำมัน', 'งา']
# ['พริกไทย', 'ป่น']
# ['ซีอิ้ว', 'ดำ']
# ['กระเทียม']
# ['น้ำ', 'สะอาด']
# ['น้ำมัน']
# ['อก', 'ไก่', 'สับ']
# ['พริก', 'แกง', 'คั่ว', 'กลิ้ง']
# ['น้ำ', 'สะอาด']
# ['น้ำตาล']
# ['น้ำปลา']
# ['น้ำมัน', 'หอย']
# ['พริกใหญ่']
# ['ใบ', 'มะกรูด', 'ซอย']
# ['อกไก่']
# ['ไข่', 'เป็ด']
# ['คะน้า']
# ['กะหล่ำ']
# ['แครอท']
# ['หอม', 'ใหญ่']
# ['มะเขือเทศ']
# ['ข้าวโพดอ่อน']
# ['ข้าว', 'สวย']
# ['น้ำตาล']
# ['ซอสปรุงรส']
# ['พริกไทย', 'ป่น']
# ['ซีอิ้ว', 'ดำ']
# ['กระเทียม']
# ['ผักชี']
# ['อกไก่']
# ['ไข่', 'เป็ด']
# ['คะน้า']
# ['กะหล่ำ']
# ['แครอท']
# ['ข้าวโพดอ่อน']
# ['น้ำตาล']
# ['ซอสปรุงรส']
# ['พริกไทย']
# ['ซีอิ้ว', 'ดำ']
# ['กระเทียม']
# ['พริกป่น']
# ['เส้น', 'หมี่', 'ข้าว', 'กล้อง']
# ['น้ำ', 'แข็ง']
# ['น้ำเสาวรส']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['พริกขี้หนูตำ']
# ['มะนาว']
# ['แครอท']
# ['หอม', 'ใหญ่']
# ['หัวหมู']
# ['ตั้งโอ๋']
# ['ผักกาดขาว']
# ['กะหล่ำ']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['กวางตุ้ง']
# ['เห็ดโคน', 'ญี่ปุ่น']
# ['แครอท']
# ['ต้น', 'หอม', 'ญี่ปุ่น']
# ['เห็ดเข็มทอง']
# ['กุ้ง']
# ['หมูสไลด์']
# ['เบคอน']
# ['ออมุก']
# ['ฮอตดอก']
# ['ต๊อกบกกี']
# ['ซอสโคชูจัง']
# ['น้ำ', 'สะอาด']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ไก่']
# ['กระเทียม']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'หอย']
# ['พริกไทย', 'ป่น']
# ['หมู', 'สาม', 'ชั้น']
# ['พริก', 'แกงเผ็ด']
# ['น้ำ', 'สะอาด']
# ['มะเขือเปาะ']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['หน่อไม้ดอง']
# ['เห็ดโคน', 'ญี่ปุ่น']
# ['แครอท']
# ['พริกไทย', 'เม็ด']
# ['พริกใหญ่']
# ['ใบ', 'กระเพรา']
# ['หมู', 'สับ']
# ['ฮอตดอก']
# ['กุ้ง']
# ['ปลาหมึก']
# ['หมู', 'สับ']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['น้ำตาล']
# ['น้ำปลา']
# ['พริกขี้หนูตำ']
# ['มะนาว']
# ['เห็ดหู', 'หนูดำ']
# ['หอม', 'ใหญ่']
# ['แครอท']
# ['ตั้งโอ๋']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ผักบุ้ง']
# ['แป้ง', 'ทอด', 'กรอบ']
# ['น้ำเย็น']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['มะนาว']
# ['พริกขี้หนูตำ']
# ['หมู', 'สับ']
# ['กุ้ง']
# ['ปลาหมึก']
# ['ฮอตดอก']
# ['น้ำ', 'แข็ง']
# ['ส้มสด']
# ['กล้วย']
# ['อัลมอนด์']
# ['น้ำมัน']
# ['กระเทียม']
# ['พริกขี้หนูตำ']
# ['หมู', 'สับ']
# ['ฮอตดอก']
# ['กุ้ง']
# ['ปลาหมึก']
# ['เส้น', 'สปาเก็ตตี้']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'หอย']
# ['แครอท']
# ['พริกไทย', 'เม็ด']
# ['ใบ', 'กระเพรา']
# ['น้ำ', 'สะอาด']
# ['หอมแดง']
# ['ตะไคร้']
# ['ใบ', 'มะกรูด']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['ไก่']
# ['เห็ด', 'นางฟ้า']
# ['พริกขี้หนูตำ']
# ['มะนาว']
# ['กุ้ง']
# ['ปลาหมึก']
# ['นมสด']
# ['ผักชี']
# ['ไข่ดาว']
# ['ไข่ไก่']
# ['ข้าว', 'สวย']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'หอย']
# ['พริกไทย', 'ป่น']
# ['คะน้า']
# ['กระเทียม']
# ['ต้นหอมซอย']
# ['ผักชี']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['มะนาว']
# ['พริกป่น']
# ['หมู', 'สับ']
# ['ต้นหอมซอย']
# ['ผักชี']
# ['ผักชี']
# ['หอมแขก']
# ['พริกขี้หนูซอย']
# ['ขนมจีน']
# ['ปลาทู']
# ['น้ำพริก', 'น้ำย้อย']
# ['น้ำมัน']
# ['กระเทียม']
# ['ผักแขนง']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซอสปรุงรส']
# ['น้ำมัน', 'หอย']
# ['ปลากระป๋อง']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ปลา', 'ดุก', 'หั่นชิ้น']
# ['แป้ง', 'ทอด', 'กรอบ']
# ['น้ำมัน']
# ['พริกขี้หนูตำ']
# ['กระเทียม']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'หอย']
# ['กระชาย']
# ['ใบ', 'มะกรูด']
# ['พริกใหญ่']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ปลา', 'อินทรีย์', 'แดด', 'เดียว']
# ['แป้ง', 'ทอด', 'กรอบ']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['มะนาว']
# ['พริกขี้หนูซอย']
# ['ตะไคร้ซอย']
# ['หอมแขก', 'ซอย']
# ['ผักชี']
# ['ถั่วลิสง']
# ['เต้า', 'หู้', 'หั่น', 'เต๋า']
# ['เห็ดหอม']
# ['คะน้า']
# ['ซอสเห็ด', 'หอม']
# ['น้ำตาล']
# ['พริกไทย']
# ['น้ำ', 'สะอาด']
# ['น้ำมัน', 'พืช']
# ['ไข่ดาว']
# ['น้ำมัน']
# ['พริกขี้หนู', 'ตำละเอียด']
# ['กระเทียม']
# ['หมู', 'สับ']
# ['น้ำตาล']
# ['น้ำปลา']
# ['น้ำมัน', 'หอย']
# ['ผง', 'ปรุงรส']
# ['ซีอิ้ว', 'ดำ']
# ['ใบ', 'กระเพรา']
# ['น้ำมัน']
# ['กระเทียม']
# ['ผักชี']
# ['พริกไทย', 'ตำละเอียด']
# ['ผง', 'พะโล้']
# ['น้ำตาล']
# ['ขาหมู']
# ['น้ำ', 'สะอาด']
# ['โป้ย', 'กั๊ก']
# ['อบเชย']
# ['ผักชี']
# ['คน', 'อร์ซอส']
# ['ซีอิ้ว', 'ดำ']
# ['เกลือ']
# ['เกียมฉ่าย']
# ['ไข่', 'เป็ด']
# ['กระดูก', 'น้ำ', 'ซุป']
# ['น้ำตาล']
# ['คน', 'อร์ซอส']
# ['น้ำปลา']
# ['น้ำ', 'มะนาว']
# ['พริกป่น']
# ['น้ำตาล']
# ['ต้นหอมซอย']
# ['หอมแขก']
# ['ผักชี']
# ['หมูยอ']
# ['ฮอตดอก']
# ['หมู', 'สับ']
# ['ขนมจีน']
# ['กระเทียม']
# ['เนื้อหมู']
# ['ไข่ไก่']
# ['เส้น', 'หมี่', 'ขาว', 'แช่', 'น้ำ']
# ['น้ำตาล']
# ['น้ำมัน', 'หอย']
# ['ซีอิ้ว', 'ดำ']
# ['พริกไทย', 'ป่น']
# ['คะน้า']
# ['กะหล่ำ']
# ['แครอท']
# ['ไก่', 'น่องสะโพก']
# ['น้ำมัน', 'หอย']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'งา']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['พริกไทย', 'ป่น']
# ['กระเทียม']
# ['น้ำมัน']
# ['กระเทียม']
# ['พริกขี้หนู']
# ['พริก', 'แห้ง']
# ['ถั่วฝักยาว']
# ['น้ำตาล']
# ['ถั่วลิสง']
# ['มะนาว']
# ['มะเขือเทศราชินี']
# ['มะละกอ', 'สับ']
# ['มะเขือเปาะ']
# ['หมูยอ']
# ['ฮอตดอก']
# ['น้ำปลา']
# ['กระเทียม']
# ['พริกขี้หนู']
# ['น้ำตาล']
# ['น้ำปลา']
# ['มะนาว']
# ['น้ำต้มสุก']
# ['ปลาหมึก']
# ['ขนมปัง']
# ['ผักกาดแก้ว']
# ['ผักกรันคอส']
# ['กรีนโอ๊ค']
# ['มะเขือเทศราชินี']
# ['ไข่ขยี้']
# ['มา', 'ยองเนส']
# ['ซอสพริก']
# ['น้ำ', 'ซุป']
# ['แครอท']
# ['หมู', 'สับ']
# ['ผักกาดแก้ว']
# ['ตำลึง']
# ['เต้า', 'หู้', 'ไข่']
# ['น้ำตาล']
# ['น้ำ', 'มะนาว']
# ['น้ำปลา']
# ['ผง', 'ปรุงรส']
# ['พริกป่น']
# ['หมู', 'สับ']
# ['หอมแขก']
# ['ต้นหอมซอย']
# ['ผักชี']
# ['ถั่วฝักยาว', 'ซอย']
# ['ขนมจีน']
# ['ปลาดุก', 'ย่าง']
# ['พริกขี้หนูซอย']
# ['น้ำมัน']
# ['เฟรนฟราย']
# ['เกลือ']
# ['ซอสมะเขือเทศ']
# ['มา', 'ยองเนส']
# ['ตะไคร้ซอย']
# ['หอมแขก']
# ['พริกขี้หนูสวน']
# ['มะนาว']
# ['ปลากระป๋อง']
# ['น้ำตาล']
# ['น้ำปลา']
# ['หัวปลีซอย']
# ['น้ำมัน']
# ['กระเทียม']
# ['พริกขี้หนูตำ']
# ['ซี่', 'โครง', 'หมู']
# ['น้ำ', 'สะอาด']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['น้ำมัน', 'หอย']
# ['ซีอิ้ว', 'ดำ']
# ['ตะไคร้ซอย']
# ['ใบ', 'มะกรูด']
# ['น้ำ', 'สะอาด']
# ['น้ำตาล']
# ['แป้ง', 'ท้าว', 'ยายม่อม']
# ['น้ำ', 'สำหรับ', 'ผสม', 'แป้ง']
# ['ข้าวโพดต้มสุก']
# ['เผือกต้ม', 'สุก']
# ['มะพร้าว', 'อ่อน']
# ['น้ำตาล']
# ['เกลือ']
# ['แป้ง', 'ข้าว', 'จ้าว']
# ['เนย']
# ['น้ำมัน']
# ['กระเทียม']
# ['ปลาหมึก']
# ['ไข่', 'เค็ม']
# ['น้ำต้มสุก']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'หอย']
# ['น้ำพริก', 'เผา']
# ['หอม', 'ใหญ่']
# ['พริกอ่อน']
# ['ต้นหอม']
# ['ตั้งโอ๋']
# ['น้ำตาล']
# ['พริกขี้หนูตำ']
# ['เห็ดเข็มทองลวก']
# ['เห็ดหูหนูลวก']
# ['หอม', 'ใหญ่']
# ['มะเขือเทศ']
# ['ตั้งโอ๋']
# ['หมู', 'สับ']
# ['หมูยอ']
# ['บะหมี่', 'กึ่ง', 'สำเร็จรูป']
# ['น้ำตาล']
# ['พริกขี้หนูตำ']
# ['กระเทียม']
# ['ผักชี']
# ['หอม', 'ใหญ่']
# ['มะเขือเทศ']
# ['หมูยอ']
# ['ไข่แดง']
# ['น้ำตาล']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['กระเทียม']
# ['มะขามเปียก']
# ['น้ำ', 'มะนาว']
# ['โซดา']
# ['ไข่ไก่']
# ['เกลือ']
# ['เหล้า', 'ขาว']
# ['น้ำมัน']
# ['เต้าหู้ทอด']
# ['คะน้า']
# ['กะหล่ำ']
# ['เห็ดโคน', 'ญี่ปุ่น']
# ['แครอท']
# ['ข้าวโพดอ่อน']
# ['ถั่วฝักยาว']
# ['บะหมี่']
# ['น้ำตาล']
# ['ซอสเห็ด', 'หอม']
# ['ซอสปรุงรส']
# ['พริกไทย', 'ป่น']
# ['ผง', 'ปรุง', 'รส', 'เห็ด', 'หอม']
# ['น้ำตาล']
# ['กระเทียม']
# ['ผักชี']
# ['น้ำมัน', 'หอย']
# ['ซีอิ้วขาว']
# ['พริกไทย', 'ป่น']
# ['ไก่', 'น่องสะโพก']
# ['หอมแดงซอย']
# ['พริกขี้หนูซอย']
# ['มะนาว']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['น้ำมัน']
# ['พริกขี้หนูตำ']
# ['กระเทียม']
# ['ไก่', 'น่องสะโพก']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'หอย']
# ['ซีอิ้ว', 'ดำ']
# ['ใบ', 'กระเพรา']
# ['น้ำมัน']
# ['พริก', 'แกงเผ็ด']
# ['ไก่', 'น่องสะโพก']
# ['เครื่อง', 'ใน', 'ไก่']
# ['หน่อไม้ดอง']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['น้ำมัน', 'หอย']
# ['ใบ', 'มะกรูด']
# ['น้ำ', 'สะอาด']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซีอิ้วขาว']
# ['พริกไทย', 'ป่น']
# ['แครอท']
# ['กะหล่ำ']
# ['หมู', 'สับ']
# ['ไข่', 'เจียว']
# ['ต้นหอม']
# ['ตั้งโอ๋']
# ['ผักชี']
# ['น้ำมัน']
# ['พริกขี้หนู', 'ตำละเอียด']
# ['กระเทียม']
# ['หมู', 'สับ']
# ['หน่อไม้เส้น']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'หอย']
# ['น้ำปลา']
# ['ซีอิ้ว', 'ดำ']
# ['ใบ', 'กระเพรา']
# ['กระเทียม']
# ['ฟักทอง']
# ['น้ำ', 'สะอาด']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'หอย']
# ['โหระพา']
# ['น่องปีก']
# ['ปลาย', 'ปีก']
# ['ปีกกลาง']
# ['เกลือ']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['น้ำ', 'สะอาด']
# ['คน', 'อร์ซอส']
# ['หัวไช', 'เท้า']
# ['ผักกาดขาว']
# ['กวางตุ้ง']
# ['น้ำตาล']
# ['มะขามเปียก']
# ['เกลือ']
# ['ผง', 'ปรุงรส']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ไข่ไก่']
# ['แป้ง', 'ทอด', 'กรอบ']
# ['มะเขือยาว']
# ['น้ำ', 'สะอาด']
# ['กระเจี๊ยบ']
# ['น้ำตาล']
# ['น้ำ', 'ซุป']
# ['หมู', 'เด้ง']
# ['ผักกาดขาว']
# ['ลูก', 'ชิ้น']
# ['ตั้งโอ๋']
# ['ต้นหอม']
# ['เต้า', 'หู้', 'ไข่']
# ['น้ำมัน']
# ['หมู', 'สับ']
# ['น้ำ', 'สะอาด']
# ['น้ำตาล']
# ['น้ำมัน', 'หอย']
# ['ซีอิ้วขาว']
# ['คน', 'อร์ซอส']
# ['พริกไทย', 'ป่น']
# ['ซีอิ้ว', 'ดำ']
# ['น้ำมัน']
# ['กระเทียม']
# ['หมู', 'สับ']
# ['บวม']
# ['น้ำตาล']
# ['คน', 'อร์ซอส']
# ['น้ำปลา']
# ['น้ำมัน', 'หอย']
# ['น้ำ', 'สะอาด']
# ['น้ำมัน']
# ['ไก่', 'น่องสะโพก']
# ['พริก', 'แกงเผ็ด']
# ['น้ำ', 'สะอาด']
# ['น้ำตาล']
# ['คน', 'อร์ซอส']
# ['น้ำปลา']
# ['น้ำมัน', 'หอย']
# ['ถั่วฝักยาว']
# ['แครอท', 'หั่น', 'ยาว']
# ['ใบ', 'มะกรูด']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ชะอม']
# ['ไข่']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['น้ำ', 'สะอาด']
# ['กระดูก', 'หมู']
# ['ผักชี']
# ['กระเทียม']
# ['มะระ']
# ['เห็ด', 'หอม', 'แช่น้ำ']
# ['ผง', 'ปรุงรส']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['พริกไทย', 'ป่น']
# ['เกลือ']
# ['ผักกาดแก้ว']
# ['เรดโอ๊ต']
# ['กรีนโอ๊ต']
# ['มะเขือเทศราชินี']
# ['ข้าวโพดต้ม']
# ['น้ำสลัด']
# ['น้ำสลัด']
# ['แตงกวา']
# ['หมู', 'สับ']
# ['ปลาทู']
# ['แครอทซอยเส้น']
# ['ถั่วฝักยาว', 'ซอย']
# ['หอมแดงซอย']
# ['พริกขี้หนูซอย']
# ['น้ำตาล']
# ['พริกป่น']
# ['ผง', 'ปรุงรส']
# ['น้ำปลา']
# ['มะนาว']
# ['ขนมจีน']
# ['น้ำตาล']
# ['ผักชี']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['ขนมเข่ง', 'หั่น', 'บาง']
# ['แป้ง', 'ทอด', 'กรอบ']
# ['ไข่']
# ['เกลือ']
# ['น้ำ', 'สะอาด']
# ['ปลายี่สก']
# ['น้ำมัน']
# ['กระเทียม']
# ['น้ำมัน', 'หอย']
# ['ซีอิ้วขาว']
# ['น้ำตาล']
# ['เต้าเจี้ยว']
# ['ผง', 'ปรุงรส']
# ['ขิงซอย']
# ['พริกใหญ่']
# ['ตั้งโอ๋']
# ['นมสด']
# ['น้ำ', 'ส้ม']
# ['กล้วย']
# ['น้ำ', 'แข็ง']
# ['น้ำมัน']
# ['กระเทียม']
# ['ผักกาดขาว']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'หอย']
# ['เต้า', 'หู้', 'ไข่']
# ['หมูกรอบ']
# ['ตั้งโอ๋']
# ['แครอท']
# ['กะหล่ำ']
# ['ข้าวโพดอ่อน']
# ['เห็ดหูหนู']
# ['ดอก', 'ไม้จีน']
# ['ฟองเต้า', 'หู้']
# ['วุ้นเส้น']
# ['น้ำตาล']
# ['ซอสปรุงรสเจ']
# ['ผง', 'ปรุงรสเจ']
# ['ซีอิ้ว', 'ดำ']
# ['ตั้งโอ๋']
# ['น้ำมัน']
# ['พริก', 'แกงเผ็ด']
# ['กระทิ']
# ['ไก่', 'น่องสะโพก']
# ['เครื่อง', 'ใน', 'ไก่']
# ['ปีกไก่']
# ['เลือด', 'ไก่']
# ['หน่อไม้เส้น']
# ['ใบ', 'มะกรูด']
# ['น้ำตาล']
# ['น้ำปลา']
# ['ผง', 'ปรุงรส']
# ['เกลือ']
# ['พริกใหญ่']
# ['โหรพา']
# ['น้ำ', 'สะอาด']
# ['แก้วมังกร']
# ['มะละกอ']
# ['นมจืด']
# ['น้ำ', 'แข็ง']
# ['Spirulina', ' ', 'powder']
# ['โกโก้']
# ['ขนมปัง']
# ['น้ำตาล']
# ['นม', 'ข้นหวาน']
# ['น้ำ', 'สะอาด']
# ['กระดูก', 'หมู']
# ['ผักชี']
# ['กระเทียม']
# ['หัวไช', 'เท้า']
# ['แครอท']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['เกลือ']
# ['พริกไทย', 'ป่น']
# ['ซอสปรุงรส']
# ['เห็ด', 'หอม', 'แช่น้ำ']
# ['น้ำมัน']
# ['กระเทียม']
# ['ไก่', 'น่องสะโพก']
# ['เครื่อง', 'ใน', 'ไก่']
# ['หอม', 'ใหญ่']
# ['พริกใหญ่']
# ['ต้นหอม']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำมัน', 'หอย']
# ['ซอสปรุงรส']
# ['กระทิ']
# ['พริก', 'แกงเขียว', 'หวาน']
# ['ไก่', 'น่องสะโพก']
# ['นอด', 'มะพร้าว', 'อ่อน']
# ['น้ำตาล']
# ['น้ำปลา']
# ['น้ำมัน', 'หอย']
# ['ผง', 'ปรุงรส']
# ['โหรพา']
# ['ไข่ไก่']
# ['พริก', 'แกงเผ็ด']
# ['หมู', 'สับ']
# ['น้ำตาล']
# ['น้ำมัน', 'หอย']
# ['แป้ง', 'ทอด', 'หรอบ']
# ['กระเทียม']
# ['เนื้อหมู']
# ['เห็ดชิเมจิ']
# ['น้ำมัน', 'หอย']
# ['ซอสปรุงรส']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['พริกไทย', 'ป่น']
# ['ไข่ไก่']
# ['บะหมี่']
# ['กวางตุ้ง', 'น้อย']
# ['คะน้า']
# ['ข้าวโพดอ่อน']
# ['แครอท']
# ['อก', 'ไก่', 'สับปรุงรส']
# ['อกไก่']
# ['พริก', 'แกงเผ็ด']
# ['น้ำ', 'สะอาด']
# ['คะน้า']
# ['เห็ดออรินจิ']
# ['แครอท']
# ['พริกใหญ่']
# ['น้ำตาล']
# ['น้ำมัน', 'หอย']
# ['น้ำปลา']
# ['ข้าวโพดอ่อน']
# ['น้ำมัน']
# ['กระเทียม']
# ['หอม', 'ใหญ่']
# ['มะเขือเทศ']
# ['แครอท']
# ['ข้าวโพดอ่อน']
# ['ไข่ไก่']
# ['คะน้า']
# ['กะหล่ำ']
# ['ข้าว', 'สวย', 'หุง', 'ค้างคืน']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซอสปรุงรส']
# ['พริกไทย', 'ป่น']
# ['ต้นหอม']
# ['ผักชี']
# ['กระเทียม']
# ['หอม', 'ใหญ่']
# ['อกไก่']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'หอย']
# ['พริกไทย', 'ป่น']
# ['แครอท']
# ['เห็ดออรินจิ']
# ['พริก', 'ใหญ่', 'เอา', 'เม็ด', 'ออก']
# ['อกไก่แล่หมัก']
# ['ผัก', 'กวางตุ้ง', 'น้อย']
# ['เห็ดออรินจิ']
# ['ข้าวโพดอ่อน']
# ['แครอท']
# ['ปลาสร้อย']
# ['น้ำปลา']
# ['ผง', 'ปรุงรส']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['น้ำมัน']
# ['กระเทียม']
# ['หมู', 'สาม', 'ชั้น']
# ['บล็อคโคลี่']
# ['ถั่วลันเตา']
# ['คะน้าฮ่องกง']
# ['น้ำตาล']
# ['น้ำมัน', 'หอย']
# ['ซีอิ้วขาว']
# ['ผง', 'ปรุงรส']
# ['พริกไทย', 'ป่น']
# ['ปีกไก่']
# ['น้ำปลา']
# ['ผง', 'ปรุงรส']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['เนื้อหมู']
# ['น้ำตาล']
# ['น้ำปลา']
# ['มะนาว']
# ['พริกป่น']
# ['ผง', 'ปรุงรส']
# ['ข้าว', 'คั่ว']
# ['หอมแดง']
# ['ต้นหอม']
# ['ผักชี']
# ['มะละกอ']
# ['นม', 'เปรี้ยว']
# ['สับปะรด']
# ['น้ำ', 'แข็ง']
# ['น้ำ', 'แช่', 'เห็ด', 'หอม']
# ['ผักชี']
# ['น่องไก่']
# ['ปีกกลาง']
# ['กระดูก', 'อ่อน']
# ['เห็ดหอม']
# ['ชุด', 'ตุ๋น', 'ยา', 'จีน']
# ['น้ำตาล']
# ['พริกไทย', 'ป่น']
# ['ผง', 'ปรุงรส']
# ['ซีอิ้วขาว']
# ['เกลือ']
# ['เยื่อไผ่']
# ['สับปะรด']
# ['องุ่น']
# ['ฝรั่ง']
# ['สละ']
# ['โยเกิร์ต']
# ['น้ำ', 'สะอาด']
# ['โปรตีน', 'แอมเวย์']
# ['แครน', 'เบอรี่อบ', 'แห้ง']
# ['น้ำ', 'แข็ง']
# ['น้ำมัน']
# ['กระเทียม']
# ['คะน้าฮ่องกง']
# ['ถั่วลันเตา']
# ['บล็อคโคลี่']
# ['เห็ดออรินจิ']
# ['น้ำตาล']
# ['ผง', 'ปรุงรส']
# ['น้ำมัน', 'หอย']
# ['ซีอิ้วขาว']
# ['พริกไทย', 'ป่น']
# ['หมู', 'สาม', 'ชั้น']
# ['เนย']
# ['พริก', 'แกงเผ็ด']
# ['น่องสะโพก']
# ['ตีนไก่']
# ['ปลาย', 'ปีก']
# ['น้ำ', 'สะอาด']
# ['มะเขือเปราะ']
# ['มะเขือพวง']
# ['น้ำตาล']
# ['เกลือ']
# ['น้ำปลา']
# ['ผง', 'ปรุงรส']
# ['พริกใหญ่']
# ['โหรพา']
# ['เสาวรส']
# ['องุ่น']
# ['ฝรั่ง']
# ['โกโก้']
# ['โกโก้']
# ['Spirulina', ' ', 'powder']
# ['น้ำ', 'แข็ง']
# ['โยเกิร์ต']
# ['น้ำ', 'สะอาด']
# ['โยเกิร์ต']
# ['องุ่น']
# ['ฝรั่ง']
# ['เสาวรส']
# ['โกโก้']
# ['น้ำ', 'ทับทิม', 'สด']
# ['น้ำ', 'แข็ง']
# ['เมล็ด', 'ฟักทอง']
# ['มันฝรั่ง']
# ['หอม', 'ใหญ่']
# ['แตงกวา', 'ญี่ปุ่น']
# ['มา', 'ยองเนส']
# ['เกลือ']
# ['พริกไทย', 'ป่น']
# ['ผักชี']
# ['กระเทียม']
# ['พริกไทย', 'ป่น']
# ['น้ำมัน']
# ['น้ำตาล']
# ['น้ำตาล']
# ['น้ำ', 'สะอาด']
# ['น่องไก่']
# ['น่องสะโพก']
# ['ตีนไก่']
# ['ชุด', 'ตุ๋น', 'ยา', 'จีน']
# ['ผง', 'ปรุงรส']
# ['ซีอิ้วขาว']
# ['ซีอิ้วขาว']
# ['ซีอิ้ว', 'ดำ']
# ['เกลือ']
# ['มะระ']
# ['เห็ดหอม']
# ['น้ำมัน', 'สำหรับ', 'ทอด']
# ['น่องไก่']
# ['ปีกไก่']
# ['ผง', 'ปรุงรส']
# ['น้ำตาล']
# ['ซีอิ้วขาว']
# ['น้ำมัน', 'หอย']
# ['พริกไทย', 'ป่น']
# ['กระเทียม']
# ['ไข่ไก่']
# ['น้ำปลา']
# ['ผง', 'ปรุงรส']
# ['น้ำมัน', 'หอย']
# ['พริกไทย', 'ป่น']
# ['หมู', 'สับ']
# ['น้ำมัน']
# ['พริก', 'แห้ง', 'แบบเผ็ด', 'มาก']
# ['พริก', 'แห้ง', 'แบบ', 'เผ็ดน้อย']
# ['ตะไคร้ซอยทอด']
# ['หอมแดง']
# ['กระเทียม']
# ['น้ำ', 'สะอาด']
# ['น้ำมัน']
# ['หมู', 'สับ']
# ['น้ำตาล']
# ['น้ำปลา']
# ['น้ำ', 'มะนาว']
# ['น้ำมัน']
# ['พริก', 'แกงพะแนง']
# ['พริก', 'แกงเผ็ด']
# ['กระดูก', 'หมู']
# ['เนย']
# ['น้ำตาล']
# ['เกลือ']
# ['น้ำมัน', 'หอย']
# ['ผง', 'ปรุงรส']
# ['ใบ', 'มะกรูด']
# ['น้ำ', 'สะอาด']
# ['ไข่ไก่']
# ['น้ำ', 'ซุป']
# ['ผง', 'ปรุงรส']
# ['น้ำมัน', 'หอย']
# ['พริกไทย', 'ป่น']
# ['หมู', 'สับ']
# ['กระเทียม']
# ['น้ำมัน']
# ['กระเทียม']
# ['ถั่วงอก']
# ['เต้า', 'หู้', 'หลอด', 'ทอด']
# ['ผง', 'ปรุงรส']
# ['น้ำมัน', 'หอย']
# ['ต้นหอม']
# ['โยเกิร์ต']
# ['องุ่น']
# ['สับปะรด']
# ['ฝรั่ง']
# ['เสาวรส']
# ['น้ำทับทิม']
# ['น้ำ', 'แข็ง']
# ['ปลากระป๋อง']
# ['หอมแขก']
# ['ตะไคร้']
# ['พริกขี้หนู']
# ['น้ำตาล']
# ['น้ำปลา']
# ['น้ำ', 'มะนาว']
# ['ผักชี']
# ['น้ำ', 'สะอาด']
# ['พริก', 'แกงเผ็ด']
# ['มะเขือเปราะ']
# ['พริกใหญ่']
# ['กระชาย']
# ['แครอท']
# ['ข้าวโพดอ่อน']
# ['ถั่วฝักยาว']
# ['กุ้ง']
# ['ปลาหมึก']
# ['เนื้อหมู']
# ['น้ำตาล']
# ['น้ำปลา']
# ['เกลือ']
# ['ผง', 'ปุงรส']
# ['ใบ', 'กระเพรา']
